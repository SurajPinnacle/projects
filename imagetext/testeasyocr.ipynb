# %%
import easyocr
import cv2
import matplotlib.pyplot as plt
from pylab import rcParams
from IPython.display import Image
# from PIL import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
Image("image.jpg")

# %%
output = reader.readtext("image.jpg", paragraph='False')

# %%
output
# Out:
# [[[[52, 6], [298, 6], [298, 54], [52, 54]],
#   'Pinnacle Consirucl 30+ Infotech Tectotogwith years'],
#  [[[333, 4], [630, 4], [630, 52], [333, 52]],
#   'Global BIM Leader pinnacleinfotech.com USA UK UAE IND | SGP JPN DEU']]

# %%
for i in range(len(output)):
    print(output[i][1])
# Out:
# Pinnacle Consirucl 30+ Infotech Tectotogwith years
# Global BIM Leader pinnacleinfotech.com USA UK UAE IND | SGP JPN DEU

# %%
cord = output[-1][0]

# %%
x_min, y_min = [min(idx) for idx in zip(*cord)]
x_max, y_max = [max(idx) for idx in zip(*cord)]

# %%
image = cv2.imread('image.jpg')
cv2.rectangle(image,(x_min, y_min), (x_max, y_max), (0,0,255), 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
