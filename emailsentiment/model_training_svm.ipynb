# %% [markdown]
# ### Importing required libraries

# %%
import pandas as pd
import numpy as np

# %%
# Folder containing Excel files
file_path = r'data\labeldata.parquet'

# %%
# Reading the data
df = pd.read_parquet(file_path)

print(f'Total Record Count: {df.shape}')
df.head()
# Out:
# Total Record Count: (5853, 4)
#                                      id  \
# 0  738a2c78-e9b7-4886-8a1b-7af4c08f3906
# 1  23e4febf-364f-464a-9a3a-80f9d89d0e6b
# 2  f0789ea4-0a5f-46c3-8adb-083766b63740
# 3  09474b0b-bc7f-4a1f-ab95-0ed2c497468a
# 4  b7438359-ce6c-42f7-bcfd-5690e875dcda
#
#                                              subject  \
# 0  RE: Yates Residence - Mechanical Contractor Me...
# 1   Re: 6771 - VeLa - Level 4 Slab Penetration Plans
# 2  RE: FW: 13027A - 20240603 - Prl - Columbia + A...
# 3  RE: West Zephyrhills Elementary - Pasco County...
# 4  RE: MLW_0001_CRS_24410_ Connacht Stadium - Exi...
#
#                                            emailtext  label
# 0  Zac Stevenson, PEPRINCIPAL | BUILDING MEPC . ....      0
# 1  You tooRespectfullyMichael BentleyGeneral Fore...      0
# 2  You can update the two 12 ducts and adjust on ...      0
# 3  You can start with Area A. Proceeded by B,C,D ...      0
# 4            You can hold off on doing this for now.      0

# %%
df.label.value_counts()
# Out:
# label
# 0    5798
# 1      55
# Name: count, dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
import re 
# Coverting the email text to lower case and removing special characters 
df['cleantext'] = df['emailtext'].apply(lambda x: re.sub(r'[^a-zA-Z\s]', '', x))
# Remove punctuation
df['cleantext'] = df['cleantext'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
# Remove numbers
df['cleantext'] = df['cleantext'].apply(lambda x: re.sub(r'\d+', '', x.lower()))

# %%
df.head()
# Out:
#                                      id  \
# 0  738a2c78-e9b7-4886-8a1b-7af4c08f3906
# 1  23e4febf-364f-464a-9a3a-80f9d89d0e6b
# 2  f0789ea4-0a5f-46c3-8adb-083766b63740
# 3  09474b0b-bc7f-4a1f-ab95-0ed2c497468a
# 4  b7438359-ce6c-42f7-bcfd-5690e875dcda
#
#                                              subject  \
# 0  RE: Yates Residence - Mechanical Contractor Me...
# 1   Re: 6771 - VeLa - Level 4 Slab Penetration Plans
# 2  RE: FW: 13027A - 20240603 - Prl - Columbia + A...
# 3  RE: West Zephyrhills Elementary - Pasco County...
# 4  RE: MLW_0001_CRS_24410_ Connacht Stadium - Exi...
#
#                                            emailtext  label  \
# 0  Zac Stevenson, PEPRINCIPAL | BUILDING MEPC . ....      0
# 1  You tooRespectfullyMichael BentleyGeneral Fore...      0
# 2  You can update the two 12 ducts and adjust on ...      0
# 3  You can start with Area A. Proceeded by B,C,D ...      0
# 4            You can hold off on doing this for now.      0
#
#                                            cleantext
# 0  zac stevenson peprincipal  building mepc   o s...
# 1  you toorespectfullymichael bentleygeneral fore...
# 2  you can update the two  ducts and adjust on p ...
# 3  you can start with area a proceeded by bcd and...
# 4             you can hold off on doing this for now

# %% [markdown]
# #### Removing the stop words

# %%
# Removing stop words 
import nltk
from nltk.corpus import stopwords

# %%
# # Download stopwords if you haven't already
# nltk.download('stopwords')

# %%
# Define the list of stopwords
stop_words = set(stopwords.words('english'))

# %%
# Keeping the negative words 
negative_words = {"no", "not", "weren't", "couldn't", "needn't", "didn't", "wouldn't", "shouldn't"}

# Remove negative words from stop_words
filtered_stop_words = stop_words - negative_words

# %%
# # Save the stop words to a text file
# with open("data\stopwords.txt", "w") as file:
#     for word in stop_words:
#         file.write(word + "\n")

# %%
# Removing stop words
df['cleantext'] = df['cleantext'].apply(
    lambda x: ' '.join([word for word in x.lower().split() if word not in filtered_stop_words])
)

# %% [markdown]
# #### Applying Lemmetization to restore the words to its root

# %%
import spacy

# %%
# Load SpaCy language model
nlp = spacy.load('en_core_web_sm')

# %%
# Apply lemmatization using SpaCy
df['cleantext'] = df['cleantext'].apply(lambda x: ' '.join([token.lemma_ for token in nlp(x)]))

# %%
df.head()
# Out:
#                                      id  \
# 0  738a2c78-e9b7-4886-8a1b-7af4c08f3906
# 1  23e4febf-364f-464a-9a3a-80f9d89d0e6b
# 2  f0789ea4-0a5f-46c3-8adb-083766b63740
# 3  09474b0b-bc7f-4a1f-ab95-0ed2c497468a
# 4  b7438359-ce6c-42f7-bcfd-5690e875dcda
#
#                                              subject  \
# 0  RE: Yates Residence - Mechanical Contractor Me...
# 1   Re: 6771 - VeLa - Level 4 Slab Penetration Plans
# 2  RE: FW: 13027A - 20240603 - Prl - Columbia + A...
# 3  RE: West Zephyrhills Elementary - Pasco County...
# 4  RE: MLW_0001_CRS_24410_ Connacht Stadium - Exi...
#
#                                            emailtext  label  \
# 0  Zac Stevenson, PEPRINCIPAL | BUILDING MEPC . ....      0
# 1  You tooRespectfullyMichael BentleyGeneral Fore...      0
# 2  You can update the two 12 ducts and adjust on ...      0
# 3  You can start with Area A. Proceeded by B,C,D ...      0
# 4            You can hold off on doing this for now.      0
#
#                                            cleantext
# 0  zac stevenson peprincipal building mepc san an...
# 1  toorespectfullymichael bentleygeneral foremans...
# 2  update two duct adjust p need shop drawing do ...
# 3  start area proceed bcd per late schedule field...
# 4                                               hold

# %% [markdown]
# #### Depedent vs Independent features

# %%
# Feature and label
X = df['cleantext']
y = df['label']

# %% [markdown]
# #### Feature Extraction
# ##### Using TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Selecting 1000 most frequent words only
vectorizer = TfidfVectorizer(max_features=1500)

# %%
# Fit and transform the cleantext data into a TF-IDF feature matrix
X_tfidf = vectorizer.fit_transform(X)

print(X_tfidf.shape)
# Out:
# (5853, 1500)

# %%
# Get the feature names (words in the vocabulary)
feature_names = vectorizer.get_feature_names_out()

# # Display the words
# print(feature_names)

# %% [markdown]
# #### Dimension Reduction using PCA

# %%
# from sklearn.decomposition import PCA

# %%
# pca = PCA(n_components=100)  # Reduce to 100 principal components
# X_pca = pca.fit_transform(X_tfidf.toarray())

# %% [markdown]
# #### Spliting the data into train and test

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.3, random_state=42, stratify=y)

# Check the shape of the training and test sets
print(X_train.shape, X_test.shape)
print(f'\nTrain label shape: {y_train.value_counts()}')
print(f'\nTest label shape: {y_test.value_counts()}')
# Out:
# (4097, 1500) (1756, 1500)
#
# Train label shape: label
# 0    4059
# 1      38
# Name: count, dtype: int64
#
# Test label shape: label
# 0    1739
# 1      17
# Name: count, dtype: int64

# %% [markdown]
# #### Handling the data imbalance using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# SMOT Params
smot_params = {
    'sampling_strategy': 0.3,
    'k_neighbors': 10,
    'random_state': 42
}

# Unpack the smot_params dictionary using ** when initializing SMOTE
smote = SMOTE(**smot_params)

# Sampled the data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print(f'y_train_resampled {y_train_resampled.value_counts()}')
# Out:
# y_train_resampled label
# 0    4059
# 1    1217
# Name: count, dtype: int64

# %%
# Calculate class imbalance ratio for scale_pos_weight
class_0_count, class_1_count = y_train.value_counts()
scale_pos_weight = ( class_0_count / class_1_count)
print(f"Scale pos weight: {scale_pos_weight}")
# Out:
# Scale pos weight: 106.8157894736842

# %%
# Importing XgBoost
from sklearn.svm import SVC
from sklearn.metrics import make_scorer, fbeta_score, recall_score

# %%
class_weight = {0: 1.0, 1: 2000.0}

# %%
param_distributions = {
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'kernel': ['linear', 'rbf', 'poly'],  # Kernel types
    'gamma': ['scale', 'auto'],  # Kernel coefficient for 'rbf', 'poly', and 'sigmoid'
    'degree': [2, 3, 4],  # Degree for the 'poly' kernel
    'class_weight': [class_weight, 'balanced', None]  # 'balanced' mode automatically adjusts class weights inversely proportional to class frequencies
}

# %%
# Initialize the SVM model
svm_model = SVC()

# Custom scoring metric using AUC-PR
scorer = make_scorer(recall_score)

# Create the RandomizedSearchCV object
random_search = RandomizedSearchCV(
    estimator=svm_model,
    param_distributions=param_distributions,
    n_iter=15,  # You can adjust this to control how many random combinations to try
    scoring=scorer,  # Use your desired scoring metric
    n_jobs=-1,  # Use all available cores
    cv=3,  # Number of cross-validation folds
    verbose=1,  # Controls verbosity: 0 (silent), 1 (progress), 2 (full output)
    random_state=42  # Ensures reproducibility
)

# %%
# Fit the grid search
random_search.fit(X_train_resampled, y_train_resampled)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# RandomizedSearchCV(cv=3, estimator=SVC(), n_iter=15, n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10, 100],
#                                         'class_weight': [{0: 1.0, 1: 2000.0},
#                                                          'balanced', None],
#                                         'degree': [2, 3, 4],
#                                         'gamma': ['scale', 'auto'],
#                                         'kernel': ['linear', 'rbf', 'poly']},
#                    random_state=42,
#                    scoring=make_scorer(recall_score, response_method='predict'),
#                    verbose=1)

# %%
# Output the best parameters
print("Best parameters found: ", random_search.best_params_)
# Out:
# Best parameters found:  {'kernel': 'linear', 'gamma': 'auto', 'degree': 2, 'class_weight': None, 'C': 100}

# %%
cv_results_df = pd.DataFrame(random_search.cv_results_)
cv_results_df = cv_results_df.sort_values(by='rank_test_score', ascending=True)
cv_results_df.head(5)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.504124      0.071018         0.162414        0.012135       linear
# 1       0.510273      0.047036         0.165195        0.006015       linear
# 2       0.509454      0.039373         0.179576        0.013838       linear
# 3       0.531028      0.023996         0.174246        0.012649       linear
# 4       1.200449      0.056565         0.506493        0.059880       linear
#
#   param_gamma  param_degree   param_class_weight  param_C  \
# 0        auto             2                 None    100.0
# 1        auto             4                 None    100.0
# 2       scale             4             balanced     10.0
# 3        auto             4  {0: 1.0, 1: 2000.0}    100.0
# 4        auto             4  {0: 1.0, 1: 2000.0}      0.1
#
#                                               params  split0_test_score  \
# 0  {'kernel': 'linear', 'gamma': 'auto', 'degree'...                1.0
# 1  {'kernel': 'linear', 'gamma': 'auto', 'degree'...                1.0
# 2  {'kernel': 'linear', 'gamma': 'scale', 'degree...                1.0
# 3  {'kernel': 'linear', 'gamma': 'auto', 'degree'...                1.0
# 4  {'kernel': 'linear', 'gamma': 'auto', 'degree'...                1.0
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0                1.0                1.0              1.0             0.0
# 1                1.0                1.0              1.0             0.0
# 2                1.0                1.0              1.0             0.0
# 3                1.0                1.0              1.0             0.0
# 4                1.0                1.0              1.0             0.0
#
#    rank_test_score
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
# Use the best estimator to predict on the test data
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Evaluate performance
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Evaluate the model (optional step)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1739
#            1       0.06      0.06      0.06        17
#
#     accuracy                           0.98      1756
#    macro avg       0.53      0.53      0.53      1756
# weighted avg       0.98      0.98      0.98      1756
#
# [[1724   15]
#  [  16    1]]
