# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
file_path = r'data\dashboard\f61f6690-3c63-4a13-b90b-725b05ab3887.csv'

# %%
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#                                      id  org_id  \
# 0  ed9038db-c6e5-4397-860a-04430fb32379     259
# 1  eb06d823-3e45-4b0c-908a-f666b65baa7a     259
# 2  1da8a31b-8962-43c2-bd1f-9d86a3481e8d     259
# 3  21c950a8-ba0d-4e33-8181-bd6f987854c2     259
# 4  4d9ac465-bd24-4be0-a425-889070760362     259
#
#                                 user_email  \
# 0  A.Solaimalathi@mdu.pinnacleinfotech.com
# 1  A.Solaimalathi@mdu.pinnacleinfotech.com
# 2  A.Solaimalathi@mdu.pinnacleinfotech.com
# 3  A.Solaimalathi@mdu.pinnacleinfotech.com
# 4  A.Solaimalathi@mdu.pinnacleinfotech.com
#
#                               plugin_id  project_id   package_name  \
# 0  0b531cd0-c9e7-4eee-aa0d-bf2659698ef1       76750  Pi Navisworks
# 1  3e821cdd-f9f7-4cc3-a2cd-7e98a8f85808       76750  Pi Mechanical
# 2  6b9bf0aa-9bf0-40fe-bc0a-88310f4e5d46       75845  Pi Mechanical
# 3  8087fdc2-cb2a-484d-b41b-e1c9a26967b3       75845        Pi Dock
# 4  8d05eb2c-b2e9-46c8-ab8c-6bf8bbf3d936       75845        Pi Dock
#
# ...

# %%
data.groupby(by=['plugin_id'])['id'].count().sort_values(ascending=False)[:10]
# Out:
# plugin_id
# c9f233c6-8522-49a3-a305-68f572f22742    281052
# a350a3f1-ee94-4770-ac69-b0153d771157    151306
# a7f0448d-f858-4785-b3a9-68b784b917e6     93138
# 1c7d17cf-7d70-444e-8808-d49bd8e69f44     29729
# 8f8b4105-983e-4e37-a46f-14e3877e10fd     28702
# ccaf12ec-d281-4bb5-91b8-bbee9070f553     22318
# dc9529c3-9e14-4647-acf6-c819c7b7c857     19093
# d970ccb9-1241-45f1-8ea7-51056c4250e2     17027
# d98de5b7-a996-416c-8d1c-c15c2f24634d     15378
# a1a109ae-696b-497b-9269-263ce7505d06     14822
# Name: id, dtype: int64

# %%
test_df = data[data['plugin_id'] =='c9f233c6-8522-49a3-a305-68f572f22742'].copy()

# %%
test_df['date_day'] = pd.to_datetime(data['desktop_usage_timestamp'], unit='s')

# %%
test_df.iloc[:,-1]
# Out:
# 19       2023-09-22 04:22:33
# 20       2023-09-27 05:11:16
# 21       2023-09-27 11:12:26
# 29       2023-09-21 06:27:54
# 40       2023-09-28 06:14:35
#                  ...
# 918606   2023-09-26 03:44:28
# 918607   2023-09-28 06:02:29
# 918608   2023-09-29 09:23:50
# 918609   2023-10-03 09:34:01
# 918610   2023-10-03 09:39:51
# Name: date_day, Length: 281052, dtype: datetime64[ns]
