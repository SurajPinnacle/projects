# %%
import os
import sys
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import configparser
import ast

config = configparser.ConfigParser()
config.read('config1.ini')

# import yaml

# with open('config.yaml', 'r') as file:
#     config = yaml.safe_load(file)
# Out:
# ['config1.ini']

# %%
pd.read_parquet(r'data\old\test.parquet').head()
# Out:
#    projectid pdh_name                name  p_values    ist_time  max_score  \
# 0        NaN     None            Warnings         4  2024-07-23       15.0
# 1        NaN     None           File Size        17  2024-07-23        5.0
# 2        NaN     None  Purgeable Elements      5067  2024-07-23        NaN
# 3        NaN     None            Worksets         1  2024-07-23        4.0
# 4        NaN     None      Design Options         0  2024-07-23        2.0
#
#    weightage  score   MHI
# 0        5.0  15.00  0.40
# 1        0.0   0.00  0.40
# 2        NaN   None  0.40
# 3        2.0   4.00  0.40
# 4        2.0   0.00  0.40

# %%
partition_key = ["partition_date"]
partition_keys = ["test"]

# %%
test = ["partition_date"] + partition_keys
test[1]
# Out:
# 'test'

# %%
import json

# Read the generated config.init file
with open('config.init', 'r') as config_file:
    result = json.load(config_file)

print(result)
# Out:
# [{'email': 'Ive uploaded more markups here: Please complete drafting for 23-043 before moving on to this project. Please also print the current arch set (plan sheets only) from the latest arch model.', 'score': 0.4}, {'email': 'Hi Arthur,The updated pdf set is attached here for your review. Also, I would like to inform you that we have considered the revision "delta 1" as "MR1" as we have replaced all "delta 1" revisions with new "MR1" revision on 14th May, as per your instruction. Please let us know if our understanding is wrong.', 'score': 0.6}, {'email': 'Arghya,Please respond to the discrepancy raised by our HVAC sub regarding the Louver size.', 'score': -1.0}, {'email': 'Per our process, did you update Autodesk Construction Cloud too? After our meeting Friday, we may need to update the shop drawings once coordination effort is done. Aaron Wright', 'score': 0.5}, {'email': 'Hi Deepak,Let me know if you received the email below.Very Respectfully,Abraham Canlas', 'score': 0.8}, {'email': 'Hi Sanjib,Please provide update.Thank you.Very Respectfully,Abraham Canlas', 'score': 0.5}, {'email': 'Sunil,See attached with comments.Thanks.Very Respectfully,Abraham Canlas', 'score': 0.6}, {'email': 'Currently the Light Pole Bases for DC4 are not included in CSIs scope of work. Is this something the Clayco team would want us to start pricing? If so, a takeoff depicting which Light Pole Bases are included in the DC4 scope would greatly assist with this if needed. Thanks, Luke', 'score': 0.0}, {'email': 'Rahul,I can', 'score': -0.1}, {'email': ', ', 'score': 0.3}, {'email': 't have updated model but they have updated drawings saved in here, please correct the HVAC drawings based on the comments about not using the most updated Arch drawings.', 'score': -0.2}, {'email': 'Good day. Please do the needful. We cannot send an ambulance at the moment as one of our ambulance is with the patient at National Care Hospital and we need an ambulance standby at the site', 'score': 0.3}, {'email': 'Per process, update Autodesk Construction Cloud too? meeting Friday, may need update shop drawings coordination effort done. Aaron Wright', 'score': 0.5}, {'email': 'Let know received email below. Respectfully, Abraham Canlas Engineer III GRANITE CONSTRUCTION COMPANY GUAM 425 Chalan San Antonio PMB 1022 Tamuning, GU 96913', 'score': 0.8}, {'email': 'Please provide update. Thank you. Respectfully, Abraham Canlas', 'score': 0.5}, {'email': 'Sunil, See attached comments. Thanks. Respectfully, Abraham Canlas Engineer III GRANITE CONSTRUCTION COMPANY GUAM 425 Chalan San Antonio PMB 1022 Tamuning, GU 96913', 'score': 0.6}, {'email': 'Classification | Internal *Noted.* Dear Ramakant, FYI *Driver-Isha-0509324047*', 'score': 0.0}, {'email': 'Classification | Internal *REMINDER * URGENTLY NEEDED COMPLETE SHEET *From:* Afzal Ahmed Farooqui', 'score': 0.1}, {'email': 'Ive uploaded more markups here: Please complete drafting 23-043 moving project. Please also print current arch set (plan sheets only) latest arch model. Thanks, Arthur Cao, SE Senior Engineer FORELL | ELSESSER D: 415 248 3027 | E: <mailto:> | W: forell.com< FORELL ELSESSER achieved label. Learn here: FORELL + Just<', 'score': 0.4}, {'email': 'Hi Sam, I', 'score': 0.6}, {'email': ', ', 'score': -1.0}, {'email': ', ', 'score': 0.5}, {'email': ', ', 'score': 0.8}, {'email': ', ', 'score': 0.5}, {'email': ', ', 'score': 0.6}, {'email': 'Currently the Light Pole Bases DC4 included CSIs scope work. something Clayco team would want us start pricing? so, takeoff depicting Light Pole Bases included DC4 scope would greatly assist needed. Thanks, Luke', 'score': 0.0}, {'email': 'Rahul, I can', 'score': -0.1}, {'email': ', ', 'score': 0.3}, {'email': 't updated model updated drawings saved here, please correct hvac drawings based comments using updated Arch drawings.', 'score': -0.2}, {'email': 'Classification | Internal *Noted.* Dear Ramakant, FYI *Driver-Isha-0509324047*', 'score': 0.3}]

# %%
# # Load examples from YAML file
# with open('config.yaml', 'r') as file:
#     examples = yaml.safe_load(file)['emails']
#     print(f'YAM file conatisn{examples}')
# Out:
# YAM file conatisn{'email': 'Sunil,See attached with comments.Thanks.Very Respectfully,Abraham Canlas', 'sentiment_score': 0.6}

# %%
# path = r'C:\Suraj\projects\test\01-sagemaker_feature_store.ipynb'
# print(os.path.dirname(path))
# Out:
# C:\Suraj\projects\test

# %%
file_path = r'data\health\email_label.parquet'

data = pd.read_parquet(file_path)
print(data.shape)
data.head()
# Out:
# (10296, 13)
#                                      id                    from_email  \
# 0  6d30273a-6d16-4c9a-b207-31261df388ba              a.cao@forell.com
# 1  6b7a51f9-201f-43fa-adc2-f23203ee00d5              a.cao@forell.com
# 2  4c74d3e9-230c-4f6b-9e36-3a9986d162d6            a.singh@dmscorp.ca
# 3  af6c2697-de52-4bca-9454-bd9ec04286e8  aaron@constructionchannel.tv
# 4  33feb1a9-3b8f-4d95-82ee-d5accabc96da      abraham.canlas@gcinc.com
#
#                                             to_email  \
# 0                      samiranm@pinnacleinfotech.com
# 1                      samiranm@pinnacleinfotech.com
# 2  anupamp@pinnacleinfotech.com, a.elshafi@rmbser...
# 3                        anants@pinnacleinfotech.com
# 4                      dkataria@pinnacleinfotech.com
#
#                                             cc_email  \
# 0       csutradhar@pinnaclecad.com, a.lin@forell.com
# 1       csutradhar@pinnaclecad.com, a.lin@forell.com
# 2  a.white@rmbservices.ca, c.ferguson@rmbservices...
# 3  tanveer.singh@jpr.pinnaclecad.com, lsharma@pin...
# 4  miguel.sapao@gcinc.com, sunilk@pinnacleinfotec...
#
#                               subject  \
# 0                 RE: 23-044 Drafting
# 1                 RE: 23-043 Drafting
# 2  RE: Exhaust Louver Size - McMaster
# 3      Re: [EXTERNAL] Re: ABMS Hangar
# 4          RE: Tristar Vault 3D Model
#
#                                                 body    date_ist  time_ist  \
# 0  Hi Sam,\n\nI've uploaded more markups here:\nh...  2024-05-16  05:13:05
# 1  Sam,\n\nI've uploaded more markups here:\nhttp...  2024-05-18  03:34:35
# 2  Arghya,\n\nPlease respond to the discrepancy r...  2024-05-13  21:12:48
# 3  Per our process, did you update Autodesk Const...  2024-04-24  21:55:04
# 4  Hi Deepak,\r\nLet me know if you received the ...  2024-04-18  05:43:17
#
#    projectid                                        clean_email  \
# 0      76461  Hi Sam,\n\nI've uploaded more markups here:\nh...
# 1      76461  Sam,\n\nI've uploaded more markups here:\nhttp...
# 2      76187  Arghya,\n\nPlease respond to the discrepancy r...
# 3      77901  Per our process, did you update Autodesk Const...
# 4      75205  Hi Deepak,\nLet me know if you received the em...
#
#                                       sentiment_NLTK     label   score
# 0  {'compound': 0.5574, 'neg': 0.0, 'neu': 0.874,...  POSITIVE  0.5574
# 1  {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...   NEUTRAL  0.0000
# 2  {'compound': 0.3182, 'neg': 0.0, 'neu': 0.859,...  POSITIVE  0.3182
# 3  {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos...   NEUTRAL  0.0000
# 4  {'compound': 0.4576, 'neg': 0.0, 'neu': 0.912,...  POSITIVE  0.4576

# %%
# Ensure the columns are of integer type
data['Year'] = data['Year'].astype(int)
data['Month'] = data['Month'].astype(int)
data['Day'] = data['Day'].astype(int)

# %%
# Create the date column
# data['date'] = pd.to_datetime(data[['Year', 'Month', 'Day']])
data['ParameterValue'] = data['ParameterValue'].astype('Int64')
data['ParameterValue'] = data['ParameterValue'].astype('Int64')
data['ProjectId'] = 76941
data['pdh_name'] = 'Lokesh Sharma'
data['LOI %'] = (data['ParameterValue'] / data['ParameterName'] * 100).round(2)

# %%
data.tail()
# Out:
#                               FileName   ElementID  UniqueCategory  \
# 164187  Snowdon Towers Sample HVAC.rvt     1499353            Pipe
# 164188  Snowdon Towers Sample HVAC.rvt     1499354            Pipe
# 164189  Snowdon Towers Sample HVAC.rvt     1499355            Pipe
# 164190  Snowdon Towers Sample HVAC.rvt     1499356            Pipe
# 164191  Snowdon Towers Sample HVAC.rvt     1499357            Pipe
#
#                Services  ParameterName  ParameterValue  LOI %  Day  Month  \
# 164187  Fire Protection             47              38  80.85   26      5
# 164188  Fire Protection             47              38  80.85   26      5
# 164189  Fire Protection             47              38  80.85   26      5
# 164190  Fire Protection             47              38  80.85   26      5
# 164191  Fire Protection             47              38  80.85   26      5
#
#         Year  ProjectId       pdh_name
# 164187  2024      76941  Lokesh Sharma
# 164188  2024      76941  Lokesh Sharma
# 164189  2024      76941  Lokesh Sharma
# 164190  2024      76941  Lokesh Sharma
# 164191  2024      76941  Lokesh Sharma

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164192 entries, 0 to 164191
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0    FileName        164192 non-null  object
#  1    ElementID       164192 non-null  int64
#  2    UniqueCategory  164192 non-null  object
#  3   Services         164192 non-null  object
#  4   ParameterName    164192 non-null  int64
#  5   ParameterValue   158026 non-null  Int64
#  6   LOI %            158026 non-null  Float64
#  7   Day              164192 non-null  int32
#  8   Month            164192 non-null  int32
#  9   Year             164192 non-null  int32
#  10  ProjectId        164192 non-null  int64
#  11  pdh_name         164192 non-null  object
# dtypes: Float64(1), Int64(1), int32(3), int64(3), object(4)
# memory usage: 13.5+ MB

# %%
data.to_parquet('data\health\LOI_Data.parquet')

# %%
df = pd.read_parquet('data\health\LOI_Data.parquet')
df.tail()
# Out:
#                               FileName   ElementID  UniqueCategory  \
# 164187  Snowdon Towers Sample HVAC.rvt     1499353            Pipe
# 164188  Snowdon Towers Sample HVAC.rvt     1499354            Pipe
# 164189  Snowdon Towers Sample HVAC.rvt     1499355            Pipe
# 164190  Snowdon Towers Sample HVAC.rvt     1499356            Pipe
# 164191  Snowdon Towers Sample HVAC.rvt     1499357            Pipe
#
#                Services  ParameterName  ParameterValue  LOI %  Day  Month  \
# 164187  Fire Protection             47              38  80.85   26      5
# 164188  Fire Protection             47              38  80.85   26      5
# 164189  Fire Protection             47              38  80.85   26      5
# 164190  Fire Protection             47              38  80.85   26      5
# 164191  Fire Protection             47              38  80.85   26      5
#
#         Year  ProjectId       pdh_name
# 164187  2024      76941  Lokesh Sharma
# 164188  2024      76941  Lokesh Sharma
# 164189  2024      76941  Lokesh Sharma
# 164190  2024      76941  Lokesh Sharma
# 164191  2024      76941  Lokesh Sharma

# %%
file_parquet = r'data\Training_Data_Cleaned.parquet'
d_data = pd.read_parquet(file_parquet)
d_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[66], line 2
#       1 file_parquet = r'data\Training_Data_Cleaned.parquet'
# ----> 2 d_data = pd.read_parquet(file_parquet)
#       3 d_data.head()
#
# File c:\Suraj\projects\test\env\lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File c:\Suraj\projects\test\env\lib\site-packages\pandas\io\parquet.py:267, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     264 if manager == "array":
#     265     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
#
# File c:\Suraj\projects\test\env\lib\site-packages\pandas\io\parquet.py:140, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     130 handles = None
#     131 if (
#     132     not fs
#     133     and not is_dir
#    (...)
#     138     # fsspec resources can also point to directories
#     139     # this branch is used for example when reading from non-fsspec URLs
# --> 140     handles = get_handle(
#     141         path_or_handle, mode, is_text=False, storage_options=storage_options
#     142     )
#     143     fs = None
#     144     path_or_handle = handles.handle
#
# File c:\Suraj\projects\test\env\lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\Training_Data_Cleaned.parquet'

# %%
os.path.dirname(os.path.realpath(path)) + "/../../"
# Out:
# 'C:\\Suraj\\projects\\test/../../'

# %%
parent_dir = os.path.dirname(os.path.realpath(path))
two_levels_up = os.path.join(parent_dir, '..', '..')
print(parent_dir)
print(two_levels_up)
# Out:
# C:\Suraj\projects\test
# C:\Suraj\projects\test\..\..

# %%
os.path.join(os.path.dirname(path), 'test_file.txt')
# Out:
# 'C:\\Suraj\\projects\\test\\test_file.txt'

# %%
os.path.split(path)
# Out:
# ('C:\\Suraj\\projects\\test', '01-sagemaker_feature_store.ipynb')

# %%
os.path.expanduser("~")
# Out:
# 'C:\\Users\\pis05408.PINNACLE'

# %%
from pdf2image import convert_from_path

# Defing the file path
file_path = r'data.head(20).head(20).head(20)\sample.pdf'

# Function to convert pdf to image
def pdf_to_images(pdf_path):
    return convert_from_path(pdf_path)

# Calling the function to convert PDF to image
images = pdf_to_images(file_path)

# %%
import configparser

# Create a ConfigParser object
config = configparser.ConfigParser()

# Read the configuration from the INI file
config.read('config.ini')
# Out:
# ['config.ini']

# %%
eval(config['plugin']['plugin_list'])
# Out:
# ['c9f233c6-8522-49a3-a305-68f572f22742',
#  'a7f0448d-f858-4785-b3a9-68b784b917e6',
#  '1c7d17cf-7d70-444e-8808-d49bd8e69f44',
#  'ea2265b1-f7fd-46e8-815a-65bdf1a052b3',
#  'b42f6c31-84c7-4ce9-9672-2b96548ae3f5',
#  'a350a3f1-ee94-4770-ac69-b0153d771157',
#  'a1a109ae-696b-497b-9269-263ce7505d06']

# %% [markdown]
# #### Reading latest file using timestamp from a shared drive

# %%
import os
import glob
# import openpyxl
import pandas as pd

# %%
# Define the directory where your files are located
directory = r'C:\Users\pis05408.PINNACLE\Desktop\Suraj\RnD\datadump'

# Define the pattern to match Excel files with epoch time suffix (e.g., '_<epoch_time>_latest')
pattern = 'sf_object_appflow_contact_*_latest.xlsx'

# Get a list of Excel files that match the pattern in the directory
excel_files = glob.glob(os.path.join(directory, pattern))

# %%
# Check if there are any matching Excel files
if not excel_files:
    print("No matching Excel files found in the directory.")
else:
    # Extract and sort the Excel files based on their epoch time suffixes
    sorted_excel_files = sorted(excel_files, key=lambda x: int(x.split('_')[-2]), reverse=True)
    
    if sorted_excel_files:
        # Get the latest Excel file (first in the sorted list)
        latest_excel_file = sorted_excel_files[0]
        
        # Read the Excel file into a DataFrame using pandas
        df = pd.read_excel(latest_excel_file)
        
        # # Now, you can work with the DataFrame 'df' as needed
        # print("DataFrame created from the latest Excel file:")
        # print(df)
        
        # Print the latest Excel file's name
        print("Latest Excel file:", latest_excel_file)
    else:
        print("No Excel files with valid epoch time suffix found in the directory.")
# Out:
# Latest Excel file: C:\Users\pis05408.PINNACLE\Desktop\Suraj\RnD\datadump\sf_object_appflow_contact_1689775460_latest.xlsx

# %%
df.head()
# Out:
#                    id  isdeleted  masterrecordid           accountid lastname  \
# 0  0032T00002q7kNHQAY      False             NaN  0012T00001uTUJUQA4      Tng
# 1  0032T00002kmap9QAA      False             NaN  0012T00001uTUJUQA4    Chong
# 2  0032T00002knZ7vQAE      False             NaN  0012T00001uTUJUQA4     Yong
# 3  00334000022II0ZAAW      False             NaN  0013400001SzSQIAA3  Jackson
# 4  0032T00002gzgTUQAY      False             NaN  0012T00001uQHTCQA4    Erwin
#
#    firstname salutation            name  otherstreet  othercity  ...  \
# 0       Bida        NaN        Bida Tng          NaN        NaN  ...
# 1       Alex        NaN      Alex Chong          NaN        NaN  ...
# 2  Chong Tse        NaN  Chong Tse Yong          NaN        NaN  ...
# 3      Julie        Ms.   Julie Jackson          NaN        NaN  ...
# 4    William        Mr.   William Erwin          NaN        NaN  ...
#
#                                    rcsfl__sendsms__c  call_response__c  \
# 0  <a href="javascript:alert(&quot;JavaScript is ...             False
# 1  <a href="javascript:alert(&quot;JavaScript is ...             False
# 2  <a href="javascript:alert(&quot;JavaScript is ...             False
# 3  <a href="javascript:alert(&quot;JavaScript is ...             False
# 4  <a href="javascript:alert(&quot;JavaScript is ...             False
#
#    dialpad__powerdialer_assigned_list__c  dialpad__powerdialer_dialed_list__c  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
#
#    dialpad__powerdialer_last_dialed_via__c  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    dialpad__totalnumberoftimesdialed__c  status_for_bim_sumit_2023__c  \
# 0                                   NaN                           NaN
# 1                                   NaN                           NaN
# 2                                   NaN                           NaN
# 3                                   NaN                           NaN
# 4                                   NaN                           NaN
#
#   tracking_1__c dialpad__iscreatedfromdialpad__c dialpad__timezone__c
# 0           NaN                            False                  NaN
# 1           NaN                            False                  NaN
# 2           NaN                            False                  NaN
# 3           NaN                            False                  NaN
# 4           NaN                            False                  NaN
#
# [5 rows x 146 columns]

# %%
import pandas as pd
import json
import numpy as np

# %%
file_path = r'C:\Users\pis05408.PINNACLE\Downloads\-103555222-2023-11-29T18_35_37'

# %%
json_objects = []

with open(file_path, 'r') as file:
    for line in file:
        try:
            # Parse each line as a JSON object
            json_object = json.loads(line)
            json_objects.append(json_object)
        except json.JSONDecodeError:
            # If a line is not a valid JSON object, ignore it
            continue

# %%
data = pd.json_normalize(json_objects)
data.head(2)
# Out:
#       Id                                               Line SyncToken  \
# 0  48962  [{'Amount': 150.0, 'DetailType': 'SubTotalLine...         3
# 1  49237  [{'Amount': 65.0, 'DetailType': 'SubTotalLineD...         1
#
#        DocNumber     TxnDate PrintStatus  \
# 0  PI/2019/34468  2019-12-10      NotSet
# 1  PI/2019/34545  2019-12-20      NotSet
#
#                                            LinkedTxn     DueDate EmailStatus  \
# 0  [{'TxnId': '48902', 'TxnType': 'StatementCharg...  2019-12-10   EmailSent
# 1  [{'TxnId': '49223', 'TxnType': 'StatementCharg...  2019-12-20   EmailSent
#
#    ExchangeRate  ... ShipAddr.PostalCode  BillAddr.City  BillAddr.Country  \
# 0           1.0  ...                 NaN            NaN               NaN
# 1           1.0  ...                 NaN            NaN               NaN
#
#    BillAddr.CountrySubDivisionCode BillAddr.PostalCode BillAddr.Lat  \
# 0                              NaN                 NaN          NaN
# 1                              NaN                 NaN          NaN
#
#   BillAddr.Long ShipAddr.Line5 BillAddr.Line5 CustomerMemo.value
# 0           NaN            NaN            NaN                NaN
# 1           NaN            NaN            NaN                NaN
#
# [2 rows x 54 columns]

# %%
temp = data.head(10).copy()

# %%
# len(temp['Line'][0])

# %%
dict_col_list = ['Line', 'LinkedTxn', 'CustomField']

for col in dict_col_list:
    for i in np.arange(len(temp[col][0])):
        temp_list = temp[col][0][i].keys()
        for key in temp_list:
            temp[col +'_'+ key + '_' + str(i+1)] = temp[col].apply(lambda x: x[0][key])

# %%
temp.columns
# Out:
# Index(['Id', 'Line', 'SyncToken', 'DocNumber', 'TxnDate', 'PrintStatus',
#        'LinkedTxn', 'DueDate', 'EmailStatus', 'ExchangeRate', 'CustomField',
#        'ApplyTaxAfterDiscount', 'TotalAmt', 'Balance', 'CustomerRef.value',
#        'CustomerRef.name', 'CurrencyRef.value', 'CurrencyRef.name',
#        'BillEmail.Address', 'SalesTermRef.value', 'SalesTermRef.name',
#        'MetaData.CreateTime', 'MetaData.LastModifiedByRef.value',
#        'MetaData.LastUpdatedTime', 'TxnTaxDetail.TotalTax', 'ShipAddr.Id',
#        'ShipAddr.Line1', 'ShipAddr.Line2', 'ShipAddr.Line3',
#        'DepartmentRef.value', 'DepartmentRef.name', 'BillAddr.Id',
#        'BillAddr.Line1', 'BillAddr.Line2', 'BillAddr.Line3', 'ShipFromAddr.Id',
#        'ShipFromAddr.Line1', 'ShipAddr.Line4', 'BillAddr.Line4',
#        'TxnTaxDetail.TxnTaxCodeRef.value', 'TxnTaxDetail.TxnTaxCodeRef.name',
#        'ShipAddr.City', 'ShipAddr.Country', 'ShipAddr.CountrySubDivisionCode',
#        'ShipAddr.PostalCode', 'BillAddr.City', 'BillAddr.Country',
#        'BillAddr.CountrySubDivisionCode', 'BillAddr.PostalCode',
#        'BillAddr.Lat', 'BillAddr.Long', 'ShipAddr.Line5', 'BillAddr.Line5',
#        'CustomerMemo.value', 'Line_Amount_1', 'Line_DetailType_1',
#        'Line_SubTotalLineDetail_1', 'LinkedTxn_TxnId_1', 'LinkedTxn_TxnType_1',
#        'LinkedTxn_TxnId_2', 'LinkedTxn_TxnType_2',
#        'CustomField_DefinitionId_1', 'CustomField_Name_1',
#        'CustomField_Type_1', 'CustomField_StringValue_1',
#        'CustomField_DefinitionId_2', 'CustomField_Name_2',
#        'CustomField_Type_2', 'CustomField_StringValue_2',
#        'CustomField_DefinitionId_3', 'CustomField_Name_3',
#        'CustomField_Type_3', 'CustomField_StringValue_3'],
#       dtype='object')

# %%
temp.head(2)
# Out:
#       Id                                               Line SyncToken  \
# 0  48962  [{'Amount': 150.0, 'DetailType': 'SubTotalLine...         3
# 1  49237  [{'Amount': 65.0, 'DetailType': 'SubTotalLineD...         1
#
#        DocNumber     TxnDate PrintStatus  \
# 0  PI/2019/34468  2019-12-10      NotSet
# 1  PI/2019/34545  2019-12-20      NotSet
#
#                                            LinkedTxn     DueDate EmailStatus  \
# 0  [{'TxnId': '48902', 'TxnType': 'StatementCharg...  2019-12-10   EmailSent
# 1  [{'TxnId': '49223', 'TxnType': 'StatementCharg...  2019-12-20   EmailSent
#
#    ExchangeRate  ... CustomField_Type_1  CustomField_StringValue_1  \
# 0           1.0  ...         StringType           Michael McFadyen
# 1           1.0  ...         StringType              Andre Bobbitt
#
#    CustomField_DefinitionId_2  CustomField_Name_2 CustomField_Type_2  \
# 0                           1            Order By         StringType
# 1                           1            Order By         StringType
#
#   CustomField_StringValue_2 CustomField_DefinitionId_3 CustomField_Name_3  \
# 0          Michael McFadyen                          1           Order By
# 1             Andre Bobbitt                          1           Order By
#
#   CustomField_Type_3 CustomField_StringValue_3
# 0         StringType          Michael McFadyen
# 1         StringType             Andre Bobbitt
#
# [2 rows x 73 columns]

# %%
for i in np.arange(1):
    print(i)
# Out:
# 0

# %%
dict_col_list = ['Line', 'LinkedTxn', 'CustomField']
# dict_col_list = ['LinkedTxn']

for col in dict_col_list:
    if len(temp[col][0]) > 1:
        for i in np.arange(len(temp[col][0])):
            temp_list = temp[col][0][i].keys()
            for key in temp_list:
                temp[col +'_'+ key + '_' + str(i+1)] = temp[col].apply(lambda x: x[0][key])
    else :
        temp_list = temp[col][0][0].keys()
        for key in temp_list:
            temp[col+'_'+ key] = temp[col].apply(lambda x: x[0][key])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Suraj\projects\test\test.ipynb Cell 26 line 1
#      <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/test.ipynb#X30sZmlsZQ%3D%3D?line=10'>11</a> temp_list = temp[col][0][0].keys()
#      <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/test.ipynb#X30sZmlsZQ%3D%3D?line=11'>12</a> for key in temp_list:
# ---> <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/test.ipynb#X30sZmlsZQ%3D%3D?line=12'>13</a>     temp[col+'_'+ key] = temp[col].apply(lambda x: x[0][key])
#
# File c:\Suraj\projects\test\env\lib\site-packages\pandas\core\series.py:4753, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
# -> 4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
#    4760     ).apply()
#
# File c:\Suraj\projects\test\env\lib\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File c:\Suraj\projects\test\env\lib\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Suraj\projects\test\env\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Suraj\projects\test\env\lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2920, in pandas._libs.lib.map_infer()
#
# c:\Suraj\projects\test\test.ipynb Cell 26 line 1
#      <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/test.ipynb#X30sZmlsZQ%3D%3D?line=10'>11</a> temp_list = temp[col][0][0].keys()
#      <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/test.ipynb#X30sZmlsZQ%3D%3D?line=11'>12</a> for key in temp_list:
# ---> <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/test.ipynb#X30sZmlsZQ%3D%3D?line=12'>13</a>     temp[col+'_'+ key] = temp[col].apply(lambda x: x[0][key])
#
# KeyError: 'SubTotalLineDetail'

# %%
temp.columns
# Out:
# Index(['Id', 'Line', 'SyncToken', 'DocNumber', 'TxnDate', 'PrintStatus',
#        'LinkedTxn', 'DueDate', 'EmailStatus', 'ExchangeRate', 'CustomField',
#        'ApplyTaxAfterDiscount', 'TotalAmt', 'Balance', 'CustomerRef.value',
#        'CustomerRef.name', 'CurrencyRef.value', 'CurrencyRef.name',
#        'BillEmail.Address', 'SalesTermRef.value', 'SalesTermRef.name',
#        'MetaData.CreateTime', 'MetaData.LastModifiedByRef.value',
#        'MetaData.LastUpdatedTime', 'TxnTaxDetail.TotalTax', 'ShipAddr.Id',
#        'ShipAddr.Line1', 'ShipAddr.Line2', 'ShipAddr.Line3',
#        'DepartmentRef.value', 'DepartmentRef.name', 'BillAddr.Id',
#        'BillAddr.Line1', 'BillAddr.Line2', 'BillAddr.Line3', 'ShipFromAddr.Id',
#        'ShipFromAddr.Line1', 'ShipAddr.Line4', 'BillAddr.Line4',
#        'TxnTaxDetail.TxnTaxCodeRef.value', 'TxnTaxDetail.TxnTaxCodeRef.name',
#        'ShipAddr.City', 'ShipAddr.Country', 'ShipAddr.CountrySubDivisionCode',
#        'ShipAddr.PostalCode', 'BillAddr.City', 'BillAddr.Country',
#        'BillAddr.CountrySubDivisionCode', 'BillAddr.PostalCode',
#        'BillAddr.Lat', 'BillAddr.Long', 'ShipAddr.Line5', 'BillAddr.Line5',
#        'CustomerMemo.value', 'Line_Amount', 'Line_DetailType',
#        'Line_SubTotalLineDetail', 'LinkedTxn_TxnId_1', 'LinkedTxn_TxnType_1',
#        'LinkedTxn_TxnId_2', 'LinkedTxn_TxnType_2',
#        'CustomField_DefinitionId_1', 'CustomField_Name_1',
#        'CustomField_Type_1', 'CustomField_StringValue_1',
#        'CustomField_DefinitionId_2', 'CustomField_Name_2',
#        'CustomField_Type_2', 'CustomField_StringValue_2',
#        'CustomField_DefinitionId_3', 'CustomField_Name_3',
#        'CustomField_Type_3', 'CustomField_StringValue_3'],
#       dtype='object')

# %%
temp.head(2)
# Out:
#       Id                                               Line SyncToken  \
# 0  48962  [{'Amount': 150.0, 'DetailType': 'SubTotalLine...         3
# 1  49237  [{'Amount': 65.0, 'DetailType': 'SubTotalLineD...         1
#
#        DocNumber     TxnDate PrintStatus  \
# 0  PI/2019/34468  2019-12-10      NotSet
# 1  PI/2019/34545  2019-12-20      NotSet
#
#                                            LinkedTxn     DueDate EmailStatus  \
# 0  [{'TxnId': '48902', 'TxnType': 'StatementCharg...  2019-12-10   EmailSent
# 1  [{'TxnId': '49223', 'TxnType': 'StatementCharg...  2019-12-20   EmailSent
#
#    ExchangeRate  ... CustomField_Type_1  CustomField_StringValue_1  \
# 0           1.0  ...         StringType           Michael McFadyen
# 1           1.0  ...         StringType              Andre Bobbitt
#
#    CustomField_DefinitionId_2  CustomField_Name_2 CustomField_Type_2  \
# 0                           1            Order By         StringType
# 1                           1            Order By         StringType
#
#   CustomField_StringValue_2 CustomField_DefinitionId_3 CustomField_Name_3  \
# 0          Michael McFadyen                          1           Order By
# 1             Andre Bobbitt                          1           Order By
#
#   CustomField_Type_3 CustomField_StringValue_3
# 0         StringType          Michael McFadyen
# 1         StringType             Andre Bobbitt
#
# [2 rows x 73 columns]

# %%
# data['Line'].apply(lambda x: x[0]['Amount'])

# %%
import pandas as pd
import re  # For regular expressions

# %%
file_path = r'data\Egnyte_File_Report_11_Oct-08_Jan23 10112023 - 01082024.csv'

# %%
data = pd.read_csv(file_path, skiprows=1)
data.head()
# Out:
# C:\Users\pis05408.PINNACLE\AppData\Local\Temp\ipykernel_18500\3349218801.py:1: DtypeWarning: Columns (5,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, skiprows=1)
#                                          File/Folder Target Path/Link  \
# 0  /Shared/DGP-MECH-08/Kilgore Industries/KGI_004...              NaN
# 1  /Shared/DGP-MECH-08/Kilgore Industries/KGI_004...              NaN
# 2  /Shared/DGP-MECH-08/Kilgore Industries/KGI_004...              NaN
# 3  /Shared/DGP-MECH-08/Kilgore Industries/KGI_004...              NaN
# 4  /Shared/DGP-MECH-08/Kilgore Industries/KGI_004...              NaN
#
#                              User/Location  User ID Transaction Type  \
# 0  Quaddus Booth ( qbooth@kilgoreind.com )      748        Lock File
# 1  Quaddus Booth ( qbooth@kilgoreind.com )      748        Lock File
# 2  Quaddus Booth ( qbooth@kilgoreind.com )      748        Lock File
# 3  Quaddus Booth ( qbooth@kilgoreind.com )      748        Lock File
# 4  Quaddus Booth ( qbooth@kilgoreind.com )      748        Lock File
#
#   Action Info       Access              Time      IP Address  \
# 0         NaN  Desktop App  10/11/23 0:02:16  216.74.235.178
# 1         NaN  Desktop App  10/11/23 0:02:26  216.74.235.178
# 2         NaN  Desktop App  10/11/23 0:02:36  216.74.235.178
# 3         NaN  Desktop App  10/11/23 0:02:46  216.74.235.178
# 4         NaN  Desktop App  10/11/23 0:06:46  216.74.235.178
#
#                                        File Checksum Device Name File Version  \
# 0  93b97fb960bfe412bd71458823598142c58338f0548e5c...         NaN          NaN
# 1  0b5f029877641523e384ca72ccc30fd3602c4357b01983...         NaN          NaN
# 2  e8ce5614ad0a2e2210d633e6ea105ea4906fe7614c6654...         NaN          NaN
# 3  f669687d62ca2871258d95275bd50d072377e5808cf7cc...         NaN          NaN
# 4  93b97fb960bfe412bd71458823598142c58338f0548e5c...         NaN          NaN
#
#    Space Used
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
data.columns
# Out:
# Index(['File/Folder', 'Target Path/Link', 'User/Location', 'User ID',
#        'Transaction Type', 'Action Info', 'Access', 'Time', 'IP Address',
#        'File Checksum', 'Device Name', 'File Version', 'Space Used'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691683 entries, 0 to 1691682
# Data columns (total 13 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   File/Folder       object
#  1   Target Path/Link  object
#  2   User/Location     object
#  3   User ID           int64
#  4   Transaction Type  object
#  5   Action Info       object
#  6   Access            object
#  7   Time              object
#  8   IP Address        object
#  9   File Checksum     object
#  10  Device Name       object
#  11  File Version      object
#  12  Space Used        int64
# dtypes: int64(2), object(11)
# memory usage: 167.8+ MB

# %%
data.shape
# Out:
# (1691683, 13)

# %%
data['Time'] = pd.to_datetime(data['Time']).dt.date
# Out:
# C:\Users\pis05408.PINNACLE\AppData\Local\Temp\ipykernel_18500\3930017959.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Time'] = pd.to_datetime(data['Time']).dt.date

# %%
data['Time'] = pd.to_datetime(data['Time'])

# %%
data.tail()
# Out:
#                                                File/Folder  \
# 1691678  /Shared/DGP-STRC-01/PCC/PCC_0007_AllPecSt24/FR...
# 1691679  /Shared/Kol-001/For Lipi Jain/Architecture all...
# 1691680  /Private/priyankad/BCA Braddell Campus/BC_DSP_...
# 1691681  /Private/priyankad/BCA Braddell Campus/BC_DSP_...
# 1691682  /Private/mshilp/ACS-008/Avenue Mall/Reference ...
#
#                                      Target Path/Link  \
# 1691678  https://pinnaclecad.egnyte.com/fl/EbelcDLHNw
# 1691679  https://pinnaclecad.egnyte.com/fl/CMful9AK8k
# 1691680  https://pinnaclecad.egnyte.com/fl/PVC83zAo0f
# 1691681  https://pinnaclecad.egnyte.com/fl/PVC83zAo0f
# 1691682                                           NaN
#
#                                              User/Location  User ID  \
# 1691678       Ranjan Kundu ( rkundu@pinnacleinfotech.com )      920
# 1691679  Anonymous access from Mohali, Punjab, India  (...       10
# 1691680  Anonymous access from Kolkata, West Bengal, In...     2242
# 1691681  Anonymous access from Kolkata, West Bengal, In...     2242
# 1691682               Nisar Khan ( nkhan@pinnaclecad.com )       34
#
#              Transaction Type                                   Action Info  \
# 1691678  Create Download Link  https://pinnaclecad.egnyte.com/fl/EbelcDLHNw
# 1691679      Preview via Link                                           NaN
# 1691680     Download via Link                                           NaN
# 1691681     Download via Link                                           NaN
# 1691682               Preview                                           NaN
#
#          Access       Time     IP Address  \
# 1691678  Web UI 2024-01-08   111.93.172.5
# 1691679    Link 2024-01-08  182.75.105.65
# 1691680    Link 2024-01-08   111.93.172.5
# 1691681    Link 2024-01-08   111.93.172.5
# 1691682  Web UI 2024-01-08  182.75.105.65
#
#                                              File Checksum Device Name  \
# 1691678                                                NaN         NaN
# 1691679  e4015811f05b045da383cc18bd36b8593b34eba8669085...         NaN
# 1691680                                                NaN         NaN
# 1691681                                                NaN         NaN
# 1691682  b46ea840e52dc5f3d057987e4625188214f2f4dac4623b...         NaN
#
#                                  File Version  Space Used
# 1691678                                   NaN           0
# 1691679                                   NaN    34978461
# 1691680                                   NaN  3234258476
# 1691681                                   NaN  4051946416
# 1691682  30fc5d81-82ad-4c0c-9173-245410f97a10      539479

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691683 entries, 0 to 1691682
# Data columns (total 13 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   File/Folder       object
#  1   Target Path/Link  object
#  2   User/Location     object
#  3   User ID           int64
#  4   Transaction Type  object
#  5   Action Info       object
#  6   Access            object
#  7   Time              datetime64[ns]
#  8   IP Address        object
#  9   File Checksum     object
#  10  Device Name       object
#  11  File Version      object
#  12  Space Used        int64
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 167.8+ MB

# %%
max(data['Time'])
# Out:
# Timestamp('2024-01-08 00:00:00')

# %%
min(data['Time'])
# Out:
# Timestamp('2023-10-11 00:00:00')

# %%
def extract_email(text):
  try:
    start = text.find("(") + 1
    end = text.find(")")
    return text[start:end].strip()
  except:
    return "Null"

# %%
data['Name'] = data['User/Location'].apply(extract_email)

# %%
data.columns
# Out:
# Index(['File/Folder', 'Target Path/Link', 'User/Location', 'User ID',
#        'Transaction Type', 'Action Info', 'Access', 'Time', 'IP Address',
#        'File Checksum', 'Device Name', 'File Version', 'Space Used', 'Name'],
#       dtype='object')

# %%
data.tail()
# Out:
#                                                File/Folder  \
# 1691678  /Shared/DGP-STRC-01/PCC/PCC_0007_AllPecSt24/FR...
# 1691679  /Shared/Kol-001/For Lipi Jain/Architecture all...
# 1691680  /Private/priyankad/BCA Braddell Campus/BC_DSP_...
# 1691681  /Private/priyankad/BCA Braddell Campus/BC_DSP_...
# 1691682  /Private/mshilp/ACS-008/Avenue Mall/Reference ...
#
#                                      Target Path/Link  \
# 1691678  https://pinnaclecad.egnyte.com/fl/EbelcDLHNw
# 1691679  https://pinnaclecad.egnyte.com/fl/CMful9AK8k
# 1691680  https://pinnaclecad.egnyte.com/fl/PVC83zAo0f
# 1691681  https://pinnaclecad.egnyte.com/fl/PVC83zAo0f
# 1691682                                           NaN
#
#                                              User/Location  User ID  \
# 1691678       Ranjan Kundu ( rkundu@pinnacleinfotech.com )      920
# 1691679  Anonymous access from Mohali, Punjab, India  (...       10
# 1691680  Anonymous access from Kolkata, West Bengal, In...     2242
# 1691681  Anonymous access from Kolkata, West Bengal, In...     2242
# 1691682               Nisar Khan ( nkhan@pinnaclecad.com )       34
#
#              Transaction Type                                   Action Info  \
# 1691678  Create Download Link  https://pinnaclecad.egnyte.com/fl/EbelcDLHNw
# 1691679      Preview via Link                                           NaN
# 1691680     Download via Link                                           NaN
# 1691681     Download via Link                                           NaN
# 1691682               Preview                                           NaN
#
#          Access       Time     IP Address  \
# 1691678  Web UI 2024-01-08   111.93.172.5
# 1691679    Link 2024-01-08  182.75.105.65
# 1691680    Link 2024-01-08   111.93.172.5
# 1691681    Link 2024-01-08   111.93.172.5
# 1691682  Web UI 2024-01-08  182.75.105.65
#
#                                              File Checksum Device Name  \
# 1691678                                                NaN         NaN
# 1691679  e4015811f05b045da383cc18bd36b8593b34eba8669085...         NaN
# 1691680                                                NaN         NaN
# 1691681                                                NaN         NaN
# 1691682  b46ea840e52dc5f3d057987e4625188214f2f4dac4623b...         NaN
#
#                                  File Version  Space Used  \
# 1691678                                   NaN           0
# 1691679                                   NaN    34978461
# 1691680                                   NaN  3234258476
# 1691681                                   NaN  4051946416
# 1691682  30fc5d81-82ad-4c0c-9173-245410f97a10      539479
#
#                                 Name
# 1691678  rkundu@pinnacleinfotech.com
# 1691679                     via link
# 1691680                     via link
# 1691681                     via link
# 1691682        nkhan@pinnaclecad.com

# %%
file_path2 = r'data\Access,_Space_Used,__1704710577997.csv'

# %%
df = pd.read_csv(file_path2)
print(df.shape)
# Out:
# (580394, 14)
# C:\Users\pis05408.PINNACLE\AppData\Local\Temp\ipykernel_18500\2594015722.py:1: DtypeWarning: Columns (2,3,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path2)

# %%
df.head()
# Out:
#          Access  Space Used Action Info Device Name File Checksum  \
# 0  Storage Sync           0         NaN         NaN           NaN
# 1  Storage Sync           0         NaN         NaN           NaN
# 2  Storage Sync           0         NaN         NaN           NaN
# 3  Storage Sync           0         NaN         NaN           NaN
# 4  Storage Sync           0         NaN         NaN           NaN
#
#   File Version                                      File/Folder  \
# 0          NaN                     /Shared/MDU-RBR-001/NSM_0013
# 1          NaN          /Shared/MDU-RBR-001/NSM_0013/New folder
# 2          NaN          /Shared/MDU-RBR-001/NSM_0013/New folder
# 3          NaN  /Shared/MDU-RBR-001/NSM_0013/REBAR CHANGE ORDER
# 4          NaN                   /Shared/MDU-RBR-001/New folder
#
#         IP Address                          Name  \
# 0  115.244.221.174  reymond@pinnacleinfotech.com
# 1  115.244.221.174  reymond@pinnacleinfotech.com
# 2  115.244.221.174  reymond@pinnacleinfotech.com
# 3  115.244.221.174  reymond@pinnacleinfotech.com
# 4  115.244.221.174  reymond@pinnacleinfotech.com
#
#                                     Target Path/Link                 Time  \
# 0     /Shared/MDU-RBR-001/NSM_0013_ The Avenues Mall  2023-11-20 00:00:00
# 1    /Shared/MDU-RBR-001/NSM_0013/REBAR CHANGE ORDER  2023-11-20 00:00:00
# 2                                                NaN  2023-11-20 00:00:00
# 3  /Shared/MDU-RBR-001/NSM_0013_ The Avenues Mall...  2023-11-20 00:00:00
# 4                       /Shared/MDU-RBR-001/NSM_0013  2023-11-20 00:00:00
#
#        Transaction Type  User ID                                 User/Location
# 0           Move Folder      741  A X REYMOND ( reymond@pinnacleinfotech.com )
# 1           Move Folder      741  A X REYMOND ( reymond@pinnacleinfotech.com )
# 2         Create Folder      741  A X REYMOND ( reymond@pinnacleinfotech.com )
# 3  Move Folder - Parent      741  A X REYMOND ( reymond@pinnacleinfotech.com )
# 4           Move Folder      741  A X REYMOND ( reymond@pinnacleinfotech.com )

# %%
# df.columns
# Out:
# Index(['Access', 'Space Used', 'Action Info', 'Device Name', 'File Checksum',
#        'File Version', 'File/Folder', 'IP Address', 'Name', 'Target Path/Link',
#        'Time', 'Transaction Type', 'User ID', 'User/Location'],
#       dtype='object')

# %%
# data.columns
# Out:
# Index(['File/Folder', 'Target Path/Link', 'User/Location', 'User ID',
#        'Transaction Type', 'Action Info', 'Access', 'Time', 'IP Address',
#        'File Checksum', 'Device Name', 'File Version', 'Space Used', 'Name'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580394 entries, 0 to 580393
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Access            580394 non-null  object
#  1   Space Used        580394 non-null  int64
#  2   Action Info       12208 non-null   object
#  3   Device Name       270 non-null     object
#  4   File Checksum     429304 non-null  object
#  5   File Version      403787 non-null  object
#  6   File/Folder       580394 non-null  object
#  7   IP Address        409200 non-null  object
#  8   Name              376401 non-null  object
#  9   Target Path/Link  194228 non-null  object
#  10  Time              580394 non-null  object
#  11  Transaction Type  580394 non-null  object
#  12  User ID           580394 non-null  int64
#  13  User/Location     580394 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 62.0+ MB

# %%
df['Time'] = pd.to_datetime(df['Time']).dt.date

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580394 entries, 0 to 580393
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Access            580394 non-null  object
#  1   Space Used        580394 non-null  int64
#  2   Action Info       12208 non-null   object
#  3   Device Name       270 non-null     object
#  4   File Checksum     429304 non-null  object
#  5   File Version      403787 non-null  object
#  6   File/Folder       580394 non-null  object
#  7   IP Address        409200 non-null  object
#  8   Name              376401 non-null  object
#  9   Target Path/Link  194228 non-null  object
#  10  Time              580394 non-null  datetime64[ns]
#  11  Transaction Type  580394 non-null  object
#  12  User ID           580394 non-null  int64
#  13  User/Location     580394 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(11)
# memory usage: 62.0+ MB

# %%
df.head()
# Out:
#          Access  Space Used Action Info Device Name File Checksum  \
# 0  Storage Sync           0         NaN         NaN           NaN
# 1  Storage Sync           0         NaN         NaN           NaN
# 2  Storage Sync           0         NaN         NaN           NaN
# 3  Storage Sync           0         NaN         NaN           NaN
# 4  Storage Sync           0         NaN         NaN           NaN
#
#   File Version                                      File/Folder  \
# 0          NaN                     /Shared/MDU-RBR-001/NSM_0013
# 1          NaN          /Shared/MDU-RBR-001/NSM_0013/New folder
# 2          NaN          /Shared/MDU-RBR-001/NSM_0013/New folder
# 3          NaN  /Shared/MDU-RBR-001/NSM_0013/REBAR CHANGE ORDER
# 4          NaN                   /Shared/MDU-RBR-001/New folder
#
#         IP Address                          Name  \
# 0  115.244.221.174  reymond@pinnacleinfotech.com
# 1  115.244.221.174  reymond@pinnacleinfotech.com
# 2  115.244.221.174  reymond@pinnacleinfotech.com
# 3  115.244.221.174  reymond@pinnacleinfotech.com
# 4  115.244.221.174  reymond@pinnacleinfotech.com
#
#                                     Target Path/Link       Time  \
# 0     /Shared/MDU-RBR-001/NSM_0013_ The Avenues Mall 2023-11-20
# 1    /Shared/MDU-RBR-001/NSM_0013/REBAR CHANGE ORDER 2023-11-20
# 2                                                NaN 2023-11-20
# 3  /Shared/MDU-RBR-001/NSM_0013_ The Avenues Mall... 2023-11-20
# 4                       /Shared/MDU-RBR-001/NSM_0013 2023-11-20
#
#        Transaction Type  User ID                                 User/Location
# 0           Move Folder      741  A X REYMOND ( reymond@pinnacleinfotech.com )
# 1           Move Folder      741  A X REYMOND ( reymond@pinnacleinfotech.com )
# 2         Create Folder      741  A X REYMOND ( reymond@pinnacleinfotech.com )
# 3  Move Folder - Parent      741  A X REYMOND ( reymond@pinnacleinfotech.com )
# 4           Move Folder      741  A X REYMOND ( reymond@pinnacleinfotech.com )

# %%
print(df.shape)
temp = df[df['Time'] < pd.to_datetime('2023-10-11')]
print(temp.shape)
# Out:
# (580394, 14)
# (247188, 14)

# %%
max(temp['Time'])
# Out:
# Timestamp('2023-10-10 00:00:00')

# %%
min(temp['Time'])
# Out:
# Timestamp('2023-09-01 00:00:00')

# %%
test_1 = pd.concat([data,temp], axis=0)

# %%
test_1.shape
# Out:
# (1938871, 14)

# %%
test_1.tail()
# Out:
#                                               File/Folder  \
# 580387  /Shared/JPR-MECH-11/AFH_0001-Sparrow Intel_Sho...
# 580388  /Shared/JPR-MECH-11/AFH_0001-Sparrow Intel_Sho...
# 580389  /Shared/JPR-MECH-11/AFH_0001-Sparrow Intel_Sho...
# 580390  /Shared/JPR-MECH-11/AFH_0001-Sparrow Intel_Sho...
# 580391  /Shared/JPR-MECH-11/AFH_0001-Sparrow Intel_Sho...
#
#                                          Target Path/Link  \
# 580387  /Shared/JPR-MECH-11/AFH_0001-Sparrow Intel/Fro...
# 580388  /Shared/JPR-MECH-11/AFH_0001-Sparrow Intel/Fro...
# 580389                                                NaN
# 580390  /Shared/JPR-MECH-11/AFH_0001-Sparrow Intel/Fro...
# 580391                                                NaN
#
#                                     User/Location  User ID Transaction Type  \
# 580387  vivek john ( vjohn@pinnacleinfotech.com )      811    Move - Parent
# 580388  vivek john ( vjohn@pinnacleinfotech.com )      811    Move - Parent
# 580389  vivek john ( vjohn@pinnacleinfotech.com )      811           Upload
# 580390  vivek john ( vjohn@pinnacleinfotech.com )      811    Move - Parent
# 580391  vivek john ( vjohn@pinnacleinfotech.com )      811           Upload
#
#        Action Info  Access       Time     IP Address  \
# 580387         NaN  Web UI 2023-10-10  182.75.105.65
# 580388         NaN  Web UI 2023-10-10  182.75.105.65
# 580389         NaN  Web UI 2023-09-22  182.75.105.65
# 580390         NaN  Web UI 2023-10-10  182.75.105.65
# 580391         NaN  Web UI 2023-09-22  182.75.105.65
#
#                                             File Checksum Device Name  \
# 580387  2-5-52428800-fd5243ac810684636cec4624a9248d3b7...         NaN
# 580388  2-5-52428800-3dfb2a10a8fad8125fa7d7012dcedbfe2...         NaN
# 580389  2-5-52428800-002244863eba8ae9b2c8c3a123e5e307d...         NaN
# 580390  2-5-52428800-3f26cb270e32db4fbb4c04b058aa6832a...         NaN
# 580391  2-5-52428800-3f26cb270e32db4fbb4c04b058aa6832a...         NaN
#
#                                 File Version  Space Used  \
# 580387  f5e4bcf4-d46b-483b-b092-08a36b3fc56d   229949440
# 580388  45e358a6-7a6c-474a-a8a9-6b62fcad49aa   230612992
# 580389  94cf84cd-306e-494f-b2d2-0d3f5289a6e7   239415296
# 580390  15e22343-06e8-4bb0-a24e-4dd0045b3a50   239497216
# 580391  15e22343-06e8-4bb0-a24e-4dd0045b3a50   239497216
#
#                               Name
# 580387  vjohn@pinnacleinfotech.com
# 580388  vjohn@pinnacleinfotech.com
# 580389  vjohn@pinnacleinfotech.com
# 580390  vjohn@pinnacleinfotech.com
# 580391  vjohn@pinnacleinfotech.com

# %%
# test_1.to_csv('data\joined_data.csv')

# %%
test_1.iloc[:,:-1].to_csv('data\joined_data.csv',index=False)

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.16.1-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Collecting tensorflow-intel==2.16.1 (from tensorflow)
#   Downloading tensorflow_intel-2.16.1-cp39-cp39-win_amd64.whl.metadata (5.0 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Requirement already satisfied: h5py>=3.10.0 in c:
MB 7.4 MB/s eta 0:00:36
#    ------------ --------------------------- 115.0/376.9 MB 7.4 MB/s eta 0:00:36
#    ------------ --------------------------- 115.3/376.9 MB 7.3 MB/s eta 0:00:36
#    ------------ --------------------------- 115.7/376.9 MB 7.2 MB/s eta 0:00:37
#    ------------ --------------------------- 116.1/376.9 MB 7.2 MB/s eta 0:00:37
#    ------------ --------------------------- 116.5/376.9 MB 8.8 MB/s eta 0:00:30
#    ------------ --------------------------- 116.9/376.9 MB 8.6 MB/s eta 0:00:31
#    ------------ --------------------------- 117.2/376.9 MB 8.5 MB/s eta 0:00:31
#    ------------ --------------------------- 117.6/376.9 MB 8.3 MB/s eta 0:00:32
#    ------------ --------------------------- 118.0/376.9 MB 8.1 MB/s eta 0:00:33
#    ------------ --------------------------- 118.4/376.9 MB 7.9 MB/s eta 0:00:33
#    ------------ --------------------------- 118.8/376.9 MB 7.7 MB/s eta 0:00:34
#    ------------ --------------------------- 119.2/376.9 MB 7.5 MB/s eta 0:00:35
#    ------------ --------------------------- 119.5/376.9 MB 7.7 MB/s eta 0:00:34
#    ------------ --------------------------- 119.9/376.9 MB 7.5 MB/s eta 0:00:35
#    ------------ --------------------------- 120.4/376.9 MB 7.4 MB/s eta 0:00:35
#    ------------ --------------------------- 120.7/376.9 MB 7.6 MB/s eta 0:00:34
#    ------------ --------------------------- 121.2/376.9 MB 9.4 MB/s eta 0:00:28
#    ------------ --------------------------- 121.5/376.9 MB 9.2 MB/s eta 0:00:28
#    ------------ --------------------------- 121.9/376.9 MB 9.0 MB/s eta 0:00:29
#    ------------ --------------------------- 122.3/376.9 MB 8.7 MB/s eta 0:00:30
#    ------------- -------------------------- 122.8/376.9 MB 8.5 MB/s eta 0:00:30
#    ------------- -------------------------- 122.8/376.9 MB 8.5 MB/s eta 0:00:30
#    ------------- -------------------------- 123.3/376.9 MB 8.2 MB/s eta 0:00:31
#    ------------- -------------------------- 123.6/376.9 MB 8.0 MB/s eta 0:00:32
#    ------------- -------------------------- 123.8/376.9 MB 7.9 MB/s eta 0:00:33
#    ------------- -------------------------- 124.1/376.9 MB 7.9 MB/s eta 0:00:33
#    ------------- -------------------------- 124.4/376.9 MB 7.7 MB/s eta 0:00:33
#    ------------- -------------------------- 124.6/376.9 MB 7.7 MB/s eta 0:00:33
#    ------------- -------------------------- 124.8/376.9 MB 7.6 MB/s eta 0:00:34
#    ------------- -------------------------- 125.0/376.9 MB 7.5 MB/s eta 0:00:34
#    ------------- -------------------------- 125.0/376.9 MB 7.5 MB/s eta 0:00:34
#    ------------- -------------------------- 125.0/376.9 MB 7.5 MB/s eta 0:00:34
#    ------------- -------------------------- 125.0/376.9 MB 7.5 MB/s eta 0:00:34
#    ------------- -------------------------- 125.0/376.9 MB 7.5 MB/s eta 0:00:34
#    ------------- -------------------------- 125.0/376.9 MB 7.5 MB/s eta 0:00:34
#    ------------- -------------------------- 125.9/376.9 MB 6.7 MB/s eta 0:00:38
#    ------------- -------------------------- 127.2/376.9 MB 7.1 MB/s eta 0:00:36
#    ------------- -------------------------- 127.4/376.9 MB 7.0 MB/s eta 0:00:36
#    ------------- -------------------------- 127.6/376.9 MB 7.0 MB/s eta 0:00:36
#    ------------- -------------------------- 127.9/376.9 MB 6.9 MB/s eta 0:00:37
#    ------------- -------------------------- 128.2/376.9 MB 6.8 MB/s eta 0:00:37
#    ------------- -------------------------- 128.5/376.9 MB 6.7 MB/s eta 0:00:37
#    ------------- -------------------------- 128.8/376.9 MB 6.7 MB/s eta 0:00:37
#    ------------- -------------------------- 129.1/376.9 MB 6.7 MB/s eta 0:00:38
#    ------------- -------------------------- 129.4/376.9 MB 6.7 MB/s eta 0:00:38
#    ------------- -------------------------- 129.7/376.9 MB 6.6 MB/s eta 0:00:38
#    ------------- -------------------------- 129.9/376.9 MB 6.5 MB/s eta 0:00:38
#    ------------- -------------------------- 129.9/376.9 MB 6.5 MB/s eta 0:00:38
#    ------------- -------------------------- 130.6/376.9 MB 6.5 MB/s eta 0:00:38
#    ------------- -------------------------- 130.9/376.9 MB 6.4 MB/s eta 0:00:39
#    ------------- -------------------------- 131.2/376.9 MB 6.4 MB/s eta 0:00:39
#    ------------- -------------------------- 131.4/376.9 MB 6.4 MB/s eta 0:00:39
#    ------------- -------------------------- 131.4/376.9 MB 6.4 MB/s eta 0:00:39
#    ------------- -------------------------- 131.4/376.9 MB 6.4 MB/s eta 0:00:39
#    ------------- -------------------------- 131.4/376.9 MB 6.4 MB/s eta 0:00:39
#    ------------- -------------------------- 131.4/376.9 MB 6.4 MB/s eta 0:00:39
#    -------------- ------------------------- 132.4/376.9 MB 5.8 MB/s eta 0:00:42
#    -------------- ------------------------- 133.3/376.9 MB 6.2 MB/s eta 0:00:40
#    -------------- ------------------------- 133.5/376.9 MB 6.1 MB/s eta 0:00:40
#    -------------- ------------------------- 133.8/376.9 MB 6.1 MB/s eta 0:00:40
#    -------------- ------------------------- 134.0/376.9 MB 6.1 MB/s eta 0:00:40
#    -------------- ------------------------- 134.0/376.9 MB 6.1 MB/s eta 0:00:40
#    -------------- ------------------------- 134.0/376.9 MB 6.1 MB/s eta 0:00:40
#    -------------- ------------------------- 134.0/376.9 MB 6.1 MB/s eta 0:00:40
#    -------------- ------------------------- 134.0/376.9 MB 6.1 MB/s eta 0:00:40
#    -------------- ------------------------- 135.1/376.9 MB 5.9 MB/s eta 0:00:42
#    -------------- ------------------------- 135.8/376.9 MB 7.0 MB/s eta 0:00:35
#    -------------- ------------------------- 136.1/376.9 MB 6.8 MB/s eta 0:00:36
#    -------------- ------------------------- 136.4/376.9 MB 6.7 MB/s eta 0:00:36
#    -------------- ------------------------- 136.8/376.9 MB 6.5 MB/s eta 0:00:37
#    -------------- ------------------------- 137.1/376.9 MB 6.4 MB/s eta 0:00:38
#    -------------- ------------------------- 137.5/376.9 MB 6.3 MB/s eta 0:00:39
#    -------------- ------------------------- 137.8/376.9 MB 6.4 MB/s eta 0:00:38
#    -------------- ------------------------- 138.0/376.9 MB 6.4 MB/s eta 0:00:38
#    -------------- ------------------------- 138.4/376.9 MB 6.4 MB/s eta 0:00:38
#    -------------- ------------------------- 138.7/376.9 MB 6.4 MB/s eta 0:00:38
#    -------------- ------------------------- 138.9/376.9 MB 6.4 MB/s eta 0:00:38
#    -------------- ------------------------- 139.1/376.9 MB 6.3 MB/s eta 0:00:38
#    -------------- ------------------------- 139.3/376.9 MB 6.3 MB/s eta 0:00:38
#    -------------- ------------------------- 139.6/376.9 MB 6.2 MB/s eta 0:00:39
#    -------------- ------------------------- 139.8/376.9 MB 6.2 MB/s eta 0:00:39
#    -------------- ------------------------- 139.9/376.9 MB 6.1 MB/s eta 0:00:39
#    -------------- ------------------------- 140.1/376.9 MB 6.1 MB/s eta 0:00:40
#    -------------- ------------------------- 140.2/376.9 MB 6.1 MB/s eta 0:00:39
#    -------------- ------------------------- 140.4/376.9 MB 6.0 MB/s eta 0:00:40
#    -------------- ------------------------- 140.6/376.9 MB 5.8 MB/s eta 0:00:41
#    -------------- ------------------------- 140.7/376.9 MB 5.8 MB/s eta 0:00:41
#    -------------- ------------------------- 140.9/376.9 MB 5.7 MB/s eta 0:00:42
#    -------------- ------------------------- 141.0/376.9 MB 5.6 MB/s eta 0:00:43
#    -------------- ------------------------- 141.3/376.9 MB 5.5 MB/s eta 0:00:43
#    --------------- ------------------------ 141.5/376.9 MB 5.5 MB/s eta 0:00:43
#    --------------- ------------------------ 141.7/376.9 MB 6.2 MB/s eta 0:00:39
#    --------------- ------------------------ 141.9/376.9 MB 6.0 MB/s eta 0:00:40
#    --------------- ------------------------ 142.1/376.9 MB 5.8 MB/s eta 0:00:41
#    --------------- ------------------------ 142.4/376.9 MB 5.7 MB/s eta 0:00:41
#    --------------- ------------------------ 142.6/376.9 MB 5.6 MB/s eta 0:00:42
#    --------------- ------------------------ 142.8/376.9 MB 5.5 MB/s eta 0:00:43
#    --------------- ------------------------ 143.1/376.9 MB 5.4 MB/s eta 0:00:44
#    --------------- ------------------------ 143.1/376.9 MB 5.4 MB/s eta 0:00:44
#    --------------- ------------------------ 143.5/376.9 MB 5.2 MB/s eta 0:00:45
#    --------------- ------------------------ 143.8/376.9 MB 5.2 MB/s eta 0:00:45
#    --------------- ------------------------ 144.0/376.9 MB 5.2 MB/s eta 0:00:45
#    --------------- ------------------------ 144.3/376.9 MB 5.8 MB/s eta 0:00:40
#    --------------- ------------------------ 144.6/376.9 MB 5.7 MB/s eta 0:00:41
#    --------------- ------------------------ 144.9/376.9 MB 5.6 MB/s eta 0:00:42
#    --------------- ------------------------ 145.2/376.9 MB 5.5 MB/s eta 0:00:43
#    --------------- ------------------------ 145.5/376.9 MB 5.4 MB/s eta 0:00:44
#    --------------- ------------------------ 145.7/376.9 MB 5.3 MB/s eta 0:00:44
#    --------------- ------------------------ 146.0/376.9 MB 5.2 MB/s eta 0:00:45
#    --------------- ------------------------ 146.3/376.9 MB 5.2 MB/s eta 0:00:45
#    --------------- ------------------------ 146.6/376.9 MB 5.2 MB/s eta 0:00:45
#    --------------- ------------------------
MB 9.4 MB/s eta 0:00:03
#    ------------------------------------- - 359.0/376.9 MB 10.4 MB/s eta 0:00:02
#    ------------------------------------- - 360.6/376.9 MB 11.5 MB/s eta 0:00:02
#    ------------------------------------- - 361.2/376.9 MB 11.7 MB/s eta 0:00:02
#    ------------------------------------- - 361.4/376.9 MB 11.3 MB/s eta 0:00:02
#    ------------------------------------- - 362.4/376.9 MB 11.7 MB/s eta 0:00:02
#    ------------------------------------- - 363.0/376.9 MB 11.9 MB/s eta 0:00:02
#    ------------------------------------- - 363.5/376.9 MB 11.7 MB/s eta 0:00:02
#    ------------------------------------- - 364.1/376.9 MB 11.7 MB/s eta 0:00:02
#    ------------------------------------- - 364.6/376.9 MB 11.9 MB/s eta 0:00:02
#    ------------------------------------- - 365.1/376.9 MB 11.7 MB/s eta 0:00:02
#    ------------------------------------- - 365.7/376.9 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- - 366.3/376.9 MB 15.6 MB/s eta 0:00:01
#    ------------------------------------- - 366.8/376.9 MB 16.4 MB/s eta 0:00:01
#    --------------------------------------  367.3/376.9 MB 15.6 MB/s eta 0:00:01
#    --------------------------------------  367.9/376.9 MB 14.9 MB/s eta 0:00:01
#    --------------------------------------  368.5/376.9 MB 14.2 MB/s eta 0:00:01
#    --------------------------------------  369.1/376.9 MB 13.6 MB/s eta 0:00:01
#    --------------------------------------  369.6/376.9 MB 13.1 MB/s eta 0:00:01
#    --------------------------------------  370.2/376.9 MB 12.6 MB/s eta 0:00:01
#    --------------------------------------  370.7/376.9 MB 12.1 MB/s eta 0:00:01
#    --------------------------------------  370.7/376.9 MB 12.1 MB/s eta 0:00:01
#    --------------------------------------  370.8/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  370.8/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  370.8/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  370.8/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  370.8/376.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  371.5/376.9 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  372.7/376.9 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  373.8/376.9 MB 9.9 MB/s eta 0:00:01
#    --------------------------------------  375.1/376.9 MB 10.7 MB/s eta 0:00:01
#    --------------------------------------  376.3/376.9 MB 11.3 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  376.9/376.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 376.9/376.9 MB 7.4 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.7 kB ? eta -:--:--
#    ---------------------------------------- 133.7/133.7 kB ? eta 0:00:00
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.64.1-cp39-cp39-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.6/4.1 MB 12.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.2/4.1 MB 12.4 MB/s eta 0:00:01
#    ------------ --------------------------- 1.3/4.1 MB 12.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.1 MB 9.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.1 MB 9.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.1 MB 9.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.1 MB 9.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.1 MB 9.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.1 MB 9.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.4/4.1 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.1 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 7.7 MB/s eta 0:00:00
# Downloading keras-3.4.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------- ----------------- 0.6/1.1 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------  1.1/1.1 MB 14.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 12.1 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/26.4 MB 15.9 MB/s eta 0:00:02
#    - -------------------------------------- 1.0/26.4 MB 11.0 MB/s eta 0:00:03
#    -- ------------------------------------- 1.6/26.4 MB 12.4 MB/s eta 0:00:03
#    -- ------------------------------------- 1.6/26.4 MB 12.4 MB/s eta 0:00:03
#    -- ------------------------------------- 1.6/26.4 MB 12.4 MB/s eta 0:00:03
#    -- ------------------------------------- 1.6/26.4 MB 12.4 MB/s eta 0:00:03
#    -- ------------------------------------- 1.6/26.4 MB 12.4 MB/s eta 0:00:03
#    -- ------------------------------------- 1.6/26.4 MB 4.6 MB/s eta 0:00:06
#    --- ------------------------------------ 2.0/26.4 MB 5.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.5/26.4 MB 7.4 MB/s eta 0:00:04
#    ------- -------------------------------- 5.1/26.4 MB 9.8 MB/s eta 0:00:03
#    --------- ------------------------------ 6.3/26.4 MB 11.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 7.1/26.4 MB 11.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.5/26.4 MB 11.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.7/26.4 MB 11.2 MB/s eta 0:00:02
#    ------------- -------------------------- 8.8/26.4 MB 11.9 MB/s eta 0:00:02
#    -------------- ------------------------- 9.3/26.4 MB 11.9 MB/s eta 0:00:02
#    -------------- ------------------------- 9.8/26.4 MB 11.8 MB/s eta 0:00:02
#    --------------- ------------------------ 10.0/26.4 MB 11.7 MB/s eta 0:00:02
#    --------------- ------------------------ 10.4/26.4 MB 11.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.9/26.4 MB 11.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 11.4/26.4 MB 11.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 11.7/26.4 MB 10.9 MB/s eta 0:00:02
#    ------------------ --------------------- 12.1/26.4 MB 14.5 MB/s eta 0:00:01
#    ------------------- -------------------- 12.6/26.4 MB 13.9 MB/s eta 0:00:01
#    ------------------- -------------------- 13.0/26.4 MB 13.4 MB/s eta 0:00:02
#    ------------------- -------------------- 13.0/26.4 MB 13.1 MB/s eta 0:00:02
#    -------------------- ------------------- 13.8/26.4 MB 12.4 MB/s eta 0:00:02
#    --------------------- ------------------ 14.2/26.4 MB 11.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 14.7/26.4 MB 11.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 15.1/26.4 MB 10.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.5/26.4 MB 10.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.7/26.4 MB 10.2 MB/s eta 0:00:02
#    ------------------------ --------------- 16.1/26.4 MB 9.9 MB/s eta 0:00:02
#    ------------------------ --------------- 16.5/26.4 MB 9.5 MB/s eta 0:00:02
#    ------------------------- -------------- 16.9/26.4 MB 9.4 MB/s eta 0:00:02
#    -------------------------- ------------- 17.2/26.4 MB 9.1 MB/s eta 0:00:02
#    -------------------------- ------------- 17.6/26.4 MB 9.0 MB/s eta 0:00:01
#    --------------------------- ------------ 18.1/26.4 MB 9.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 18.5/26.4 MB 9.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 19.0/26.4 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.4/26.4 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.8/26.4 MB 8.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.8/26.4 MB 8.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.8/26.4 MB 8.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.8/26.4 MB 8.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.8/26.4 MB 8.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.8/26.4 MB 8.6 MB/s eta 0:00:01
#    ------------------------------ --------- 20.0/26.4 MB 7.1 MB/s eta 0:00:01
#    ------------------------------- -------- 20.5/26.4 MB 7.4 MB/s eta 0:00:01
#    ------------------------------- -------- 20.5/26.4 MB 7.4 MB/s eta 0:00:01
#    ------------------------------- -------- 20.5/26.4 MB 7.4 MB/s eta 0:00:01
#    ------------------------------- -------- 20.5/26.4 MB 7.4 MB/s eta 0:00:01
#    ------------------------------- -------- 20.5/26.4 MB 7.4 MB/s eta 0:00:01
#    ------------------------------- -------- 20.5/26.4 MB 7.4 MB/s eta 0:00:01
#    -------------------------------- ------- 21.6/26.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 23.0/26.4 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------- -- 24.8/26.4 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------  26.4/26.4 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 8.6 MB/s eta 0:00:00
# Downloading ml_dtypes-0.3.2-cp39-cp39-win_amd64.whl (127 kB)
#    ---------------------------------------- 0.0/127.7 kB ? eta -:--:--
#    ---------------------------------------- 127.7/127.7 kB ? eta 0:00:00
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 14.2 MB/s eta 0:00:01
#    ------ --------------------------------- 0.9/5.5 MB 14.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.4/5.5 MB 11.1 MB/s eta 0:00:01
#    -------------- ------------------------- 1.9/5.5 MB 11.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.5 MB 11.8 MB/s eta 0:00:01
#    --------------------- ------------------ 2.9/5.5 MB 11.6 MB/s eta 0:00:01
#    ------------------------ --------------- 3.4/5.5 MB 11.5 MB/s eta 0:00:01
#    -------------------------- ------------- 3.6/5.5 MB 11.4 MB/s eta 0:00:01
#    -------------------------- ------------- 3.6/5.5 MB 11.4 MB/s eta 0:00:01
#    -------------------------- ------------- 3.6/5.5 MB 11.4 MB/s eta 0:00:01
#    -------------------------- ------------- 3.6/5.5 MB 11.4 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.5 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 5.1/5.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 9.0 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --------------- ------------------------ 0.6/1.5 MB 12.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 10.5 MB/s eta 0:00:00
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ---------------------------------------- 0.0/105.4 kB ? eta -:--:--
#    ---------------------------------------- 105.4/105.4 kB 6.3 MB/s eta 0:00:00
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.11.0-cp39-cp39-win_amd64.whl (240 kB)
#    ---------------------------------------- 0.0/240.0 kB ? eta -:--:--
#    --------------------------------------- 240.0/240.0 kB 14.4 MB/s eta 0:00:00
# Installing collected packages: namex, libclang, flatbuffers, tensorflow-io-gcs-filesystem, tensorboard-data-server, optree, opt-einsum, ml-dtypes, grpcio, google-pasta, gast, astunparse, absl-py, markdown, keras, tensorboard, tensorflow-intel, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.5.4 google-pasta-0.2.0 grpcio-1.64.1 keras-3.4.0 libclang-18.1.1 markdown-3.6 ml-dtypes-0.3.2 namex-0.0.8 opt-einsum-3.3.0 optree-0.11.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-intel-2.16.1 tensorflow-io-gcs-filesystem-0.31.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.1
