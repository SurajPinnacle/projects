# %%
import pandas as pd
import numpy as np

# %%
file_path = r'C:\Users\pis05408.PINNACLE\Desktop\Suraj\RnD\plant3D\Iso.dcf'

# %%
from pycspro import DictionaryParser
import json

raw_dictionary = open(file_path, 'r', encoding='latin1').read()
dictionary_parser = DictionaryParser(raw_dictionary)
parsed_dictionary = dictionary_parser.parse()
print(json.dumps(parsed_dictionary, indent=4))
# Out:
# ---------------------------------------------------------------------------
# MissingSectionHeaderError                 Traceback (most recent call last)
# c:\Suraj\projects\test\plant3d_dcf.ipynb Cell 3 line 6
#       <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/plant3d_dcf.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> raw_dictionary = open(file_path, 'r', encoding='latin1').read()
#       <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/plant3d_dcf.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> dictionary_parser = DictionaryParser(raw_dictionary)
# ----> <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/plant3d_dcf.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> parsed_dictionary = dictionary_parser.parse()
#       <a href='vscode-notebook-cell:/c%3A/Suraj/projects/test/plant3d_dcf.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> print(json.dumps(parsed_dictionary, indent=4))
#
# File c:\Suraj\projects\test\venv\lib\site-packages\pycspro\DictionaryParser.py:240, in DictionaryParser.parse(self)
# ...

# %%
# import chardet

# rawdata = open(file_path, 'rb').read()
# result = chardet.detect(rawdata)
# charenc = result['encoding']

# with open(file_path, 'r', encoding='latin1') as file:
#     content = file.read()

# file.close()

# %%
# from datetime import datetime
# curr_date = str(datetime.now().date())
# curr_date
# Out:
# '2023-10-18'

# %%
path = r'\\10.1.20.41\Everyone\Divyansh\18-10-2023\Piping_Pipe_PNP.csv'
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    PnPID PnPClassName  PnPStatus  PnPRevision  \
# 0    605         Pipe          0          109
# 1    614         Pipe          0          109
# 2    626         Pipe          0          110
# 3    638         Pipe          0          109
# 4    650         Pipe          0          109
#
#                                 PnPGuid  PnPTimestamp  \
# 0  64e604b6-52ef-4252-acda-b2b9ecaf97dd  6.383270e+17
# 1  798b9ae2-805b-4abb-8152-60d513808b28  6.383270e+17
# 2  1942f80a-ecfb-4a1d-a08d-20f1c0e0915e  6.383270e+17
# 3  bd81326e-0cb3-45d6-9043-ade5fcc26edb  6.383270e+17
# 4  9ee94f3f-7773-4946-9be5-5bc6c4204778  6.383270e+17
#
#                            PartFamilyId  \
# 0  c12271bf-ca35-4a55-8d2f-95fda9f7b86f
# 1  c12271bf-ca35-4a55-8d2f-95fda9f7b86f
# 2  c12271bf-ca35-4a55-8d2f-95fda9f7b86f
# 3  c12271bf-ca35-4a55-8d2f-95fda9f7b86f
# 4  c12271bf-ca35-4a55-8d2f-95fda9f7b86f
#
#                                   PartFamilyLongDesc CompatibleStandard  \
# ...
