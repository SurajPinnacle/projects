# %%
import os
import sys

import json
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
file_path = r"C:\Users\pis05408.PINNACLE\Downloads\testw.parquet"

# %%
data = pd.read_parquet(file_path)
data.shape
# Out:
# (1, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1 non-null      object
#  1   from_email    1 non-null      object
#  2   to_email      1 non-null      object
#  3   cc_email      1 non-null      object
#  4   subject       1 non-null      object
#  5   body          1 non-null      object
#  6   date_ist      1 non-null      object
#  7   time_ist      1 non-null      object
#  8   projectid     1 non-null      int64
#  9   cleaned_body  1 non-null      object
#  10  label         1 non-null      object
#  11  score         1 non-null      float32
#  12  run_time      1 non-null      int64
# dtypes: float32(1), int64(2), object(10)
# memory usage: 228.0+ bytes

# %%
data.head(5)
# Out:
#                                      id                        from_email  \
# 0  a8f4c7be-8e4b-4a8e-a51e-4b0cb60f34b8                  a.cao@forell.com
# 1  a15e935c-9647-4494-a684-3b44935f36ec                 abha@carrasco.com
# 2  50653515-ccec-458a-9aa5-1efe4161b35c        aemamian@modernniagara.com
# 3  dda9296e-c3e5-4b77-bead-543ca57ef2f6  afzal.farooqui@nesmapartners.com
# 4  9dfc1d8d-c58c-49cf-8c72-fc3adad4b66a            ahreen@occvirginia.com
#
#                                             to_email  \
# 0                      samiranm@pinnacleinfotech.com
# 1                       ankitab@pinnacleinfotech.com
# 2  mhasan@pinnacleinfotech.com, arghyad@pinnaclei...
# 3                       sureshs@pinnacleinfotech.com
# 4  kartheeswaran@pinnacleinfotech.com, ayyappan@p...
#
#                                             cc_email  \
# 0       csutradhar@pinnaclecad.com, a.lin@forell.com
# 1  asaxena@pinnacleinfotech.com, debashree@pinnac...
# ...

# %%
# Function to flatten the nested dictionary
def flatten_dict(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            if all(isinstance(i, dict) for i in v):
                for i, sub_dict in enumerate(v):
                    items.extend(flatten_dict(sub_dict, f"{new_key}_{i}", sep=sep).items())
            else:
                items.append((new_key, v))
        else:
            items.append((new_key, v))
    return dict(items)

# %%
# Read JSON data from a file
file_path = 'data\Json\jsontest.json'  # Update this path to the actual file path
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
# Flatten the data
flattened_data = [flatten_dict(item) for item in data]

# Create DataFrame
df = pd.DataFrame(flattened_data)

# %%
df.head()
# Out:
#   id                           facility_id  \
# 0     590cdc42-64ae-44cd-8084-82c5724fc9a4
# 1     590cdc42-64ae-44cd-8084-82c5724fc9a4
# 2     590cdc42-64ae-44cd-8084-82c5724fc9a4
# 3     590cdc42-64ae-44cd-8084-82c5724fc9a4
# 4     590cdc42-64ae-44cd-8084-82c5724fc9a4
#
#          tandem_config_tandem_model_id tandem_config_tandem_element_id  \
# 0  urn:adsk.dtm:ljNxHLbpS6-HzHwX2KIdNg     -ipZVeBIRPqkNvaU5pPBiQAAAAA
# 1  urn:adsk.dtm:ljNxHLbpS6-HzHwX2KIdNg     uxMB688CRSK7m8svaG6RfgAAAAA
# 2  urn:adsk.dtm:ljNxHLbpS6-HzHwX2KIdNg     31zHJkh7TdigwaffDyDxsgAAAAA
# 3  urn:adsk.dtm:ljNxHLbpS6-HzHwX2KIdNg     eyDnyKp1QvSG68h8JfnRiAAAAAA
# 4  urn:adsk.dtm:ljNxHLbpS6-HzHwX2KIdNg     1rtDQpEjS0aMS2Q4BatFVQAAAAA
#
#   tandem_config_asset_id                                      name  \
# 0                                   Temperature  & Humidity Sensor
# 1                         South Wing First Floor Indoor AQI Sensor
# 2                           Lawn Grass Soil Moisture Sensor-Zone05
# ...

# %%
df.shape
# Out:
# (10, 151)
