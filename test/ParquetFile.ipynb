# %%
import os
import sys
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
file_path1 = r'data\email_dump.csv'

# %%
data = pd.read_csv(file_path1)
data.head()
# Out:
#                                      id                      from_email  \
# 0  c6904740-a079-4dd7-89b3-f4a3998a1f7c   jayla.horton@msssolutions.com
# 1  223afaea-5c55-4dda-bff8-c07085e8d5c4        k.hemphill@fitzplumb.com
# 2  a6900667-6119-41ca-849a-3e136c84ec57              adamf@amfmep.co.uk
# 3  90873f0a-93ec-4e87-9666-4eb93fd1d112  omar.zaarour@nesmapartners.com
# 4  a1a9db98-4c58-4346-8efd-287e8ec84df5            mdaniel@joneseng.com
#
#                                             to_email  \
# 0                       aghosh1@pinnacleinfotech.com
# 1  t.heard@fitzplumb.com, jaganathd@pinnacleinfot...
# 2  krai@pinnacleinfotech.com, arpanc@pinnacleinfo...
# 3  swarupg@pinnacleinfotech.com, basel.salaas@nes...
# 4                        nkoley@pinnacleinfotech.com
#
#                                             cc_email  \
# 0  steven.cantrill@msssolutions.com, chris.little...
# 1  j.casey@fitzplumb.com, asaha@pinnacleinfotech.com
# ...

# %%
data.to_parquet('data/email_parquet.parquet')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   projectid                     29 non-null     int64
#  1   breakupid                     29 non-null     int64
#  2   pdh_name                      29 non-null     object
#  3   contracthours                 29 non-null     object
#  4   contractvalue                 21 non-null     object
#  5   requestdate                   29 non-null     datetime64[ns]
#  6   requested_by                  29 non-null     object
#  7   approved_by                   29 non-null     object
#  8   approveddate                  29 non-null     datetime64[ns]
#  9   approvalstatus                29 non-null     bool
#  10  correctedhour                 0 non-null      object
#  11  correctedvalue                0 non-null      object
# ...

# %%
file_path2 = r'data\RCA_259_N.parquet'
data1 = pd.read_parquet(file_path2)
data1.head()
# Out:
#                                      id org_id  \
# 0  3df73b21-a313-415f-9d7e-6453da41025b    259
# 1  f21722e7-e1cd-48c7-923e-03359ade113d    259
#
#                              user_email                             plugin_id  \
# 0  mayank.vyas@jpr.pinnacleinfotech.com  c9f233c6-8522-49a3-a305-68f572f22742
# 1  mayank.vyas@jpr.pinnacleinfotech.com  c9f233c6-8522-49a3-a305-68f572f22742
#
#   project_id   package_name package_version plugin_version  \
# 0      77047  Pi Mechanical           3.5.0          1.0.0
# 1      77047  Pi Mechanical           3.5.0          1.0.0
#
#    num_elements_processed  time_taken_ms desktop_usage_timestamp   timestamp  \
# 0                       1          386.0              1707268921  1707268947
# 1                       1         6029.0              1707268922  1707268947
#
#                                             filename        software_name  \
# 0  C:\Users\pis02770\AppData\Local\Autodesk\Revit...  Autodesk Revit 2021
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2 non-null      object
#  1   org_id                   2 non-null      object
#  2   user_email               2 non-null      object
#  3   plugin_id                2 non-null      object
#  4   project_id               2 non-null      object
#  5   package_name             2 non-null      object
#  6   package_version          2 non-null      object
#  7   plugin_version           2 non-null      object
#  8   num_elements_processed   2 non-null      int32
#  9   time_taken_ms            2 non-null      float32
#  10  desktop_usage_timestamp  2 non-null      object
#  11  timestamp                2 non-null      object
#  12  filename                 2 non-null      object
#  13  software_name            2 non-null      object
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2 non-null      object
#  1   org_id                   2 non-null      object
#  2   user_email               2 non-null      object
#  3   plugin_id                2 non-null      object
#  4   project_id               2 non-null      object
#  5   package_name             2 non-null      object
#  6   package_version          2 non-null      object
#  7   plugin_version           2 non-null      object
#  8   num_elements_processed   2 non-null      int32
#  9   time_taken_ms            2 non-null      float32
#  10  desktop_usage_timestamp  2 non-null      object
#  11  timestamp                2 non-null      object
#  12  filename                 2 non-null      object
#  13  software_name            2 non-null      object
# ...

# %%
file_path2 = r'data\RCA_287.parquet'
data2 = pd.read_parquet(file_path2)
data2.head()
# Out:
#                                      id org_id              user_email  \
# 0  ffd16178-0167-4202-af77-59237e6c3977    287  gheyse@swansonrink.com
#
#                               plugin_id project_id package_name  \
# 0  57b940c2-5ced-476c-b7a4-3528660f42a1          0       Pi SWR
#
#   package_version plugin_version  num_elements_processed  time_taken_ms  \
# 0           1.0.0          1.0.0                       1          377.0
#
#   desktop_usage_timestamp   timestamp  \
# 0              1707330961  1707330962
#
#                                             filename        software_name  \
# 0  Autodesk Docs://LAS T1 Node 4/3080.R23_LAS T1 ...  Autodesk Revit 2023
#
#     mac_address       ip_address           device_type pdh_id is_error  \
# 0  00090FAA0001  205.168.107.219  RestSharp/106.12.0.0      0     None
#
#   error_message
# 0          None

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       1 non-null      object
#  1   org_id                   1 non-null      object
#  2   user_email               1 non-null      object
#  3   plugin_id                1 non-null      object
#  4   project_id               1 non-null      object
#  5   package_name             1 non-null      object
#  6   package_version          1 non-null      object
#  7   plugin_version           1 non-null      object
#  8   num_elements_processed   1 non-null      int32
#  9   time_taken_ms            1 non-null      float32
#  10  desktop_usage_timestamp  1 non-null      object
#  11  timestamp                1 non-null      object
#  12  filename                 1 non-null      object
#  13  software_name            1 non-null      object
# ...
