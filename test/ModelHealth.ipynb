# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

import dtale

# %%
# Load the uploaded CSV file
file_path_h = 'data\old\modelhealthdata.csv'

# Load the uploaded CSV file
data = pd.read_csv(file_path_h)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Project ID  20 non-null     float64
#  1   PDH Name    20 non-null     object
#  2   Revit File  20 non-null     object
#  3   Name        20 non-null     object
#  4   Result      20 non-null     object
#  5   Count       20 non-null     float64
#  6   Day         20 non-null     float64
#  7   Month       20 non-null     float64
#  8   Year        20 non-null     float64
#  9   Date        20 non-null     object
# dtypes: float64(5), object(5)
# memory usage: 1.8+ KB

# %%
# Create a date range for the next 30 days
# Get the current date
now = datetime.now()
start_date = now - relativedelta(months=1)
date_range = [start_date + timedelta(days=i) for i in range(30)]


# Initialize an empty list to store dataframes
dummy_data_list = []

# Generate dummy data
for date in date_range:
    daily_data = []
    for index, row in data.iterrows():
        # Create a base count value with 10% variance
        base_count = row['Count']
        if not pd.isna(base_count):
            count = max(0, int(np.random.normal(base_count, base_count * 0.1)))
        else:
            count = 0
        
        # Create a dictionary for the new row
        daily_data.append({
            'Project ID': row['Project ID'],
            'PDH Name': row['PDH Name'],
            'Revit File': row['Revit File'],
            'Name': row['Name'],
            'Result': row['Result'],
            'Count': count,
            'Date': date.strftime('%Y-%m-%d'),
            'Day': date.day,
            'Month': date.month,
            'Year': date.year
        })
    
    # Convert daily_data list to DataFrame and add to dummy_data_list
    daily_df = pd.DataFrame(daily_data)
    dummy_data_list.append(daily_df)

# Concatenate all daily dataframes into a single dataframe
dummy_data = pd.concat(dummy_data_list, ignore_index=True)

dummy_data = dummy_data.dropna(subset=['Project ID'])

# %%
dummy_data['Project ID'] = dummy_data['Project ID'].astype('Int64')
dummy_data['Count'] = dummy_data['Count'].astype('Int64')
dummy_data['Date'] = pd.to_datetime(dummy_data['Date'])
dummy_data['Day'] = dummy_data['Date'].dt.day
dummy_data['Month'] = dummy_data['Date'].dt.month
dummy_data['Year'] = dummy_data['Date'].dt.year

# %%
dummy_data.columns
# Out:
# Index(['Project ID', 'PDH Name', 'Revit File', 'Name', 'Result', 'Count',
#        'Date', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
dummy_data.head(25)
# Out:
#     Project ID       PDH Name                       Revit File  \
# 0        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 1        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 2        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 3        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 4        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 5        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 6        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 7        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 8        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 9        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 10       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 11       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 12       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 13       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 14       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 15       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 16       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 17       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 18       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 19       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 21       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 22       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 23       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 24       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 25       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
#
#                                  Name  Result  Count       Date  Day  Month  \
# 0                            Warnings  Report     12 2024-05-21   21      5
# 1                           File Size  Report    169 2024-05-21   21      5
# 2                   Purgable Elements  Report    412 2024-05-21   21      5
# 3                            Worksets  Report      5 2024-05-21   21      5
# 4                      Design Options  Report      0 2024-05-21   21      5
# 5                 Duplicate Instances  Report     49 2024-05-21   21      5
# 6                  Linked Revit Files  Report     10 2024-05-21   21      5
# 7                    Linked CAD Files  Report      1 2024-05-21   21      5
# 8                  Imported CAD files  Report      0 2024-05-21   21      5
# 9                  Imported SKP files  Report      0 2024-05-21   21      5
# 10                      Raster Images  Report      0 2024-05-21   21      5
# 11         Non built-in Object Styles  Report      8 2024-05-21   21      5
# 12                              Views  Report     74 2024-05-21   21      5
# 13                             Sheets  Report    153 2024-05-21   21      5
# 14                Views Not On Sheets  Report     40 2024-05-21   21      5
# 15   Views with Hidden Model Elements  Report      2 2024-05-21   21      5
# 16                       Model Groups  Report     83 2024-05-21   21      5
# 17                      Detail Groups  Report      3 2024-05-21   21      5
# 18                  In-Place Families  Report     19 2024-05-21   21      5
# 19  Total Elements Inside Revit 2022.  Report   5408 2024-05-21   21      5
# 21                           Warnings  Report     18 2024-05-22   22      5
# 22                          File Size  Report    211 2024-05-22   22      5
# 23                  Purgable Elements  Report    420 2024-05-22   22      5
# 24                           Worksets  Report      6 2024-05-22   22      5
# 25                     Design Options  Report      0 2024-05-22   22      5
#
#     Year
# 0   2024
# 1   2024
# 2   2024
# 3   2024
# 4   2024
# 5   2024
# 6   2024
# 7   2024
# 8   2024
# 9   2024
# 10  2024
# 11  2024
# 12  2024
# 13  2024
# 14  2024
# 15  2024
# 16  2024
# 17  2024
# 18  2024
# 19  2024
# 21  2024
# 22  2024
# 23  2024
# 24  2024
# 25  2024

# %%
d = dtale.show(dummy_data)
d.open_browser()

# %%
# # dummy_data.Date.value_counts()
# dummy_data = dummy_data.drop_duplicates(['Project ID', 'PDH Name', 'Revit File', 'Name', 'Date'])
# # dummy_data = dummy_data.drop_duplicates(['Project Id', 'PDH Name', ' FileName', ' ElementID', ' UniqueCategory',
# #        'Services', 'Date'])

# %%
# Save the generated dummy data to a CSV file
output_file_path = 'data\health\Model_Health_Data'
# output_file_path = 'data\health\LOI_Data'

# %%
dummy_data.to_csv(output_file_path+'.csv', index=False)
dummy_data.to_parquet(output_file_path+'.parquet', index=False)
# Out:
# 2024-06-21 11:47:16,320 - INFO     - Executing shutdown due to inactivity...
# 2024-06-21 11:47:20,409 - INFO     - Executing shutdown...
# 2024-06-21 11:47:20,422 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer

# %%
data = pd.read_parquet(output_file_path+'.parquet')

# %%
data.head()
# Out:
#    Project ID       PDH Name                       Revit File  \
# 0       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 1       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 2       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 3       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 4       76941  Lokesh Sharma  rac_advanced_sample_project.rvt
#
#                 Name  Result  Count  Day  Month  Year       Date
# 0           Warnings  Report     14   21      5  2024 2024-05-21
# 1          File Size  Report    185   21      5  2024 2024-05-21
# 2  Purgable Elements  Report    445   21      5  2024 2024-05-21
# 3           Worksets  Report      6   21      5  2024 2024-05-21
# 4     Design Options  Report      0   21      5  2024 2024-05-21

# %%
import dtale
d = dtale.show(data)
d.open_browser()
# Out:
# c:\Suraj\projects\test\env\lib\site-packages\dtale\query.py:158: FutureWarning:
#
# The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#
# c:\Suraj\projects\test\env\lib\site-packages\dtale\query.py:158: FutureWarning:
#
# The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#
# c:\Suraj\projects\test\env\lib\site-packages\dtale\query.py:158: FutureWarning:
#
# The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#
# c:\Suraj\projects\test\env\lib\site-packages\dtale\query.py:158: FutureWarning:
#
# The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#
# c:\Suraj\projects\test\env\lib\site-packages\dtale\query.py:158: FutureWarning:
#
# The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#
# c:\Suraj\projects\test\env\lib\site-packages\dtale\query.py:158: FutureWarning:
#
# The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.

# %%
data.shape
# Out:
# (600, 10)

# %%
data.columns
# Out:
# Index(['Project ID', 'PDH Name', 'Revit File', 'Name', 'Result', 'Count',
#        'Day', 'Month', 'Year', 'Date'],
#       dtype='object')

# %%
data = data.drop_duplicates(['Project ID', 'PDH Name', 'Revit File', 'Name', 'Date'])

# %%
data.shape
# Out:
# (600, 10)

# %%
data.head(40)
# Out:
#      Project ID       PDH Name                       Revit File  \
# 0         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 1         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 2         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 3         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 4         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 5         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 6         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 7         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 8         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 9         76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 10        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 11        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 12        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 13        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 14        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 15        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 16        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
# 17        76941  Lokesh Sharma  rac_advanced_sample_project.rvt
#