# %%
## https://www.programcreek.com/python/example/110661/cv2.createLineSegmentDetector

# %%
import cv2
import numpy as np

# %%
image_path = r'data\input_image.jpg'

# %%
# Read the image
image = cv2.imread(image_path, cv2.IMREAD_COLOR)

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# cv2.imwrite('image.jpg', image)

# %%
# Create an LSD detector object
lsd = cv2.createLineSegmentDetector(0)

# Detect line segments
# lines = lsd.detect(gray)[0]
lines, width, prec, nfa = lsd.detect(gray)

# # Use Canny edge detection
# edges = cv2.Canny(gray, 50, 150, apertureSize=3)

# %%
# print(width)
# lines

# %%
# list to store widths of the lines 
for i, line in enumerate(lines):
    x1, y1, x2, y2 = map(int, line[0])
    # Calling the width function to get the width of the line
    # width = estimate_line_width(edges, line)
    # width_list.append(width)

    # Choose color based on width
    if width[i][0] > 5.0:
        color = (0, 0, 255)    # Red for thick lines
    elif width[i][0] > 4.5:
        color = (255, 0, 0)    # Blue for thick lines
    elif width[i][0] > 4:
        color = (255, 0, 255)  # Magenta for thick lines
    elif width[i][0] > 3.5:
        color = (0, 255, 0)    # Green for thick lines
    elif width[i][0] > 3.0:
        color = (255, 255, 0)  # Gyan for thick lines
    else:
        color = (128, 128, 128)  # Gray for thick lines
    
    
    # Assigning the line with color
    # cv2.line(image, (x1, y1), (x2, y2), (0, 0, 255), 2)
    cv2.line(image, (x1, y1), (x2, y2), color, 2)

# %%
# # Display the result
# cv2.imshow('Detected Lines', image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
cv2.imwrite('data/lsdLines_1.jpg', image)
# Out:
# True

# %%
# type(width[0][0])
# Out:
# numpy.float64

# %%
width_list = [width[i][0] for i in range(len(width))]

# %%
# width_list

# %%
u_width_list = list(set(width_list))
print(f'Total length of the width list: {len(width_list)}')
print(f'Total length of the unique width list: {len(u_width_list)}')
# Out:
# Total length of the width list: 18131
# Total length of the unique width list: 16939

# %%
print(sorted(u_width_list, reverse=True))
# Out:
# [24.169981986031676, 21.54968112980952, 17.454133725947774, 16.77832554057825, 16.378193315046417, 16.272006914336075, 16.09585778116669, 15.821811173413778, 15.776864263895387, 14.921418547567567, 14.716993359138588, 14.419559545653874, 13.711928234247427, 13.611772269152892, 13.409409826107215, 12.52443777781242, 12.277492014584896, 12.23811352235762, 12.160811187691367, 12.117893289273916, 11.906745120349417, 11.890367153587738, 11.85958725617119, 11.70868101620088, 11.683057000046642, 11.675706188919515, 11.61265176786305, 11.537599725813195, 11.470130275561234, 11.35778146754813, 11.146646850990624, 10.684878290078665, 10.638315446378508, 10.576271687333092, 10.388892213793092, 10.383538085751285, 10.374370579840546, 10.311319106737725, 10.310376883872259, 10.190454559377935, 10.174418847588317, 10.100766020703507, 10.09623923823745, 9.996777064884263, 9.960403931567829, 9.951136408098174, 9.918986928242534, 9.907713708309617, 9.845832812524241, 9.834433082821036, 9.794260024834559, 9.78700605868687, 9.78263834583817, 9.776611805368344, 9.773460207726004, 9.77283012912006, 